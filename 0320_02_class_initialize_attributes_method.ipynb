# %% [markdown]
# <a href="https://colab.research.google.com/github/hwanginseo04/-/blob/main/0320_02_class_initialize_attributes_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color='blue'> Class = Chef**
# > ### **Understanding Class와 속성, 인스터스**

# %%
class Cheff:
    pass

# %% [markdown]
# - **Cheff** : without parentheses is a class definition.
# >> It defines a blueprint for creating objects. Cheff is **an empty class with no attributes or methods defined.** It's just a shell that can be used to create instances of the Cheff class.
#
# - **Cheff()**:
# >> Cheff() with parentheses is used **to create an instance (object) of the Cheff class**. When you call Cheff(), it creates a new object based on the blueprint defined by the Cheff class. This object can then be used to store data (attributes) and perform actions (methods) defined within the class.

# %%
Cheff
# Out:
# __main__.Cheff

# %%
__name__ == '__main__'
# Out:
# True

# %%
Cheff()

# %% [markdown]
# #### **함수와 다른 점**

# %%
def hello():
    print('Hi Hello')

# %%
hello
# Out:
# <function __main__.hello()>

# %%
hello()
# Out:
# Hi Hello

# %%
Cheff.id = '01'  # Cheff 클래스 자체에 새로운 클래스 속성을 추가

# %%
Cheff.id
# Out:
# '01'

# %%
Cheff.name = 'Tom'
Cheff.name
# Out:
# 'Tom'

# %%
Cheff
# Out:
# __main__.Cheff

# %%
# 인스턴스 생성
c1 = Cheff()
c2 = Cheff()

print(c1.name) # 출력: Tom
print(c2.name) # 출력: Tom
# Out:
# Tom
# Tom

# %% [markdown]
# ### **Class**
# >> **class Cheff:**
# >>> **pass**
#
# >> **user_1 = Cheff()**
#
# > ##### **1. 두 개의 객체가 생성**
# > ##### **2. Cheff라는 클라스이름은 클래스 객체를 바인딩(Binding)**
# > ##### **3. user_1 변수는 Cheff 클래스 타입의 객체를 바인딩**
# > ##### **<font color='blue'>4. 클래스와 객체가 각자 고유의 메모리 공간을 갖는다**
#
# - 클래스는 붕어빵틀(Cheff)로 객체(user_1)는 붕어빵틀로부터 구어진 붕어빵

# %%
class Cheff:
    pass

# %%
user_1 = Cheff()       # Class를 객체화

# %%
id(Cheff())
# Out:
# 133753823034304

# %%
id(c1)
# Out:
# 133753823032576

# %%
id(c2)
# Out:
# 133753823024176

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# Cheff      type        <class '__main__.Cheff'>
# c1         Cheff       <__main__.Cheff object at 0x79a5fd1bf500>
# c2         Cheff       <__main__.Cheff object at 0x79a5fd1bd430>
# hello      function    <function hello at 0x79a5fd197880>
# user_1     Cheff       <__main__.Cheff object at 0x79a5fd1bfad0>
# user_2     Cheff       <__main__.Cheff object at 0x79a5fd1d4740>

# %%
id(Cheff)
# Out:
# 77888800

# %%
id(user_1)
# Out:
# 133753823034064

# %%
user_2 = Cheff()
id(user_2)
# Out:
# 133753823119168

# %% [markdown]
# **Why the Memory Addresses are Different:**
# - **Temporary Instance (id(Cheff())):**
# > Each call to Cheff() creates a new, unique instance of the Cheff class.
# When you call id(Cheff()), a new instance is created temporarily for the id function call, and this instance is not stored or referenced after the id call.
# Since it is a new instance, it has a unique memory address each time you call Cheff().
#
# - **Persistent Instance (id(user_1)):**
# > When you call user_1 = Cheff(), an instance of Cheff is created and stored in the variable user_1.
# The id(user_1) call retrieves the memory address of this specific, persistent instance.

# %%
# user_1 인스턴스에 새로운 인스턴스 속성을 추가
# user의 attributes 'id'를 생성하고 attributes의 값(vlaue)을 '001'이라고 함

user_1.id = '001'

# %%
user_1.username = 'tom'

# %%
user_1.marry = True

# %%
user_1.age = 25

# %%
print(user_1.id)
# Out:
# 001

# %%
print(user_1.username)
# Out:
# tom

# %%
print(user_1.age)
# Out:
# 25

# %%
print(user_1.marry)
# Out:
# True

# %% [markdown]
# 일반적으로는 클래스 내부에 변수를 미리 선언하지만, 파이썬에서는 클래스를 정의한 후에도 외부에서 마치 포스트잇을 붙이듯이 새로운 속성을 추가할 수 있습니다.
#
#
# 💡 주의할 점
# 실무에서는 이 방식보다는 __init__ 메서드를 사용해 객체를 만들 때 값을 넣어주는 방식을 권장합니다. 클래스 자체에 값을 고정해버리면 나중에 요리사마다 이름을 다르게 관리하기가 까다로워질 수 있거든요.
#
# 혹시 이 Cheff 클래스를 활용해 개별 요리사 객체마다 다른 아이디와 이름을 부여하는 코드로 발전시켜 볼까요? 원하신다면 __init__을 사용한 정석적인 코드를 만들어 봅시다.

# %% [markdown]
# #### **Chef를 쉽게 만드는 방법, 붕어빵 처럼 찍어내기**
# ### **<font color='blue'>Object = Tom, Mary, Henry, Magaret, Edward**
# <img src= 'https://img.freepik.com/free-vector/cook-collection-concept_23-2148514280.jpg?w=996&t=st=1690469366~exp=1690469966~hmac=1e8376fab19963197a896074cbd6f00d3f5a6e79360a9cd532bc4e5b6d6d8839' width = 700 height= 400>
#
#
# ## **<font color='blue'> chef = Chef(), object = Class()**
# ## **객체(chef)를 만들고 속성(attributes)과 메소드(method) 생성하기**

# %% [markdown]
# ## **1. 속성(attributes)**

# %% [markdown]
# - **user(cheff)가 수천 명이면 ?? 난감하네**
# ## Constructor
# ### Initialize(in·i·tial·ize/iˈniSHəˌlīz/) verb 가 필요
# #### COMPUTING
# - 1. set to the value or put in the condition appropriate to the start of an operation.
# "the counter is initialized to one"
# - 2. format (a computer disk).

# %% [markdown]
# > ### Constructor
# ---
# ### **class Car:**
# > **def __init __ (self):**
#
# >   - #### Initialize attributes
#
# <img src='https://pynative.com/wp-content/uploads/2021/07/create_declare_instance_variable.png'>
#
# >> ### **클래스에 속성을 추가하면 해당 클래스의 모든 인스턴스가 이 새로운 속성을 공유**
# >> ### **즉, id와 name 속성은 모든 Cheff 인스턴스에 적용**

# %%
class User:
# Out:
#   File "/tmp/ipykernel_457/1570416349.py", line 1
#     class User:
#                ^
# SyntaxError: incomplete input

# %%
class User:
    def __init__(self, user_id, user_name):
        self.id = user_id
        self.name = user_name

user_1 = User('001', 'Tom')
user_2 = User('002', 'Jerry')

# %%
# prompt: 100명의 user를 만들려면

users = []
for i in range(100):
  user_id = str(i).zfill(3)
  user_name = f"user_{i}"
  user = User(user_id, user_name)
  users.append(user)

# %%
users[1].id

# %%
', '.join([users[i].id for i in range(100)])

# %%
', '.join([users[i].name for i in range(100)])

# %%
user_1.id

# %%
user_2.name

# %%
class User:
    def __init__(self, user_id, user_name, user_age):
        self.id = user_id
        self.name = user_name
        self.age = user_age

user_1 = User('001', 'Tom', 35)
user_2 = User('002', 'Jerry', 33)

# %%
user_1.age

# %% [markdown]
# ## **2. 메소드(method)**
#
# >> ### Cheff 대신 차량을 가정하여 Class를 만들어 보자
# ---
# ### **class Car:**
# > **def __init __ (self):**
# >   - ##### Initialize attributes (seats = 5)
# >   - **HAS (Attiributes)**
#
# > **def enter_race_mode():**
# >   - ##### chage attributes (seats = 1) for entering F1
# >   - **Does (Method, Change the attributes)**
#
#
# ---
#
# - car = Carbluprint()라면 자동차의 좌석수, 문짝 개수 등의 기본 속성을 정의
# - F1에 출전하려면 좌석을 1개로 줄여야 한다(method)
#
#
# <img src='https://media.istockphoto.com/id/1263896499/ko/%EC%82%AC%EC%A7%84/%EC%9D%BC%EB%AA%B0%EC%97%90-%EA%B7%B8%EB%9E%9C%EB%93%9C-%EC%8A%A4%ED%83%A0%EB%93%9C-%EA%B7%BC%EC%B2%98-%EA%B2%BD%EB%A7%88%EC%9E%A5%EC%97%90%EC%84%9C-%EB%B9%A0%EB%A5%B4%EA%B2%8C-%EC%9D%B4%EB%8F%99-%EA%B2%BD%EC%A3%BC-%EC%9E%90%EB%8F%99%EC%B0%A8.webp?b=1&s=170667a&w=0&k=20&c=Yi_YSedv8Cebb9AbZzFYaLEx0bzW4pYqzA2MD5yQHN0='>

# %%
class Car:
    # 1. 생성자: 객체가 만들어질 때 호출되는 함수
    def __init__(self, brand, model, color):
        self.brand = brand  # 브랜드
        self.model = model  # 모델명
        self.color = color  # 색상
        self.speed = 0      # 현재 속도 (기본값 0)

    # 2. 메서드: 자동차의 동작 (가속)
    def accelerate(self, amount):
        self.speed += amount
        print(f"{self.model}이(가) {amount}km/h 가속하여 현재 {self.speed}km/h입니다.")

    # 3. 메서드: 자동차의 동작 (정지)
    def stop(self):
        self.speed = 0
        print(f"{self.model}이(가) 멈췄습니다.")

# %%
# 'my_car'라는 실제 자동차 객체 생성
my_car = Car("Hyundai", "Ionic 6", "White")

# 'your_car'라는 또 다른 자동차 객체 생성
your_car = Car("Tesla", "Model 3", "Black")

# 각 자동차의 정보 출력
print(f"내 차는 {my_car.brand} {my_car.model}입니다.")
# 출력: 내 차는 Hyundai Ionic 6입니다.

# 자동차 동작시키기
my_car.accelerate(50)  # Ionic 6이 50km/h로 달립니다.
your_car.accelerate(80) # Model 3는 80km/h로 달립니다.
# Out:
# 내 차는 Hyundai Ionic 6입니다.
# Ionic 6이(가) 50km/h 가속하여 현재 50km/h입니다.
# Model 3이(가) 80km/h 가속하여 현재 80km/h입니다.

# %% [markdown]
# ## **과제 1. faker를 사용하여 1000명의 데이터를 class를 이용하여 만들어라**
#
# - [click faker](https://faker.readthedocs.io/en/master/)

# %%
from faker import Faker

fake = Faker('ko_KR')

# 사용자 클래스 정의
class User:
    def __init__(self, user_id):
        self.id = user_id
        self.name = fake.name()
        self.email = fake.email()
        self.address = fake.address()
        self.phone = fake.phone_number()

    def to_dict(self):
        return {
            "id": self.id,
            "name": self.name,
            "email": self.email,
            "address": self.address,
            "phone": self.phone
        }

# 1000명 생성
users = [User(i + 1).to_dict() for i in range(1000)]

# 확인 (앞 5명만 출력)
for user in users[:1000]:
    print(user)
# Out:
# {'id': 1, 'name': '안영환', 'email': 'sanghunseo@example.com', 'address': '충청북도 정선군 봉은사로 581 (민서이차면)', 'phone': '032-195-7582'}
# {'id': 2, 'name': '최민지', 'email': 'ihyeonu@example.net', 'address': '울산광역시 강남구 서초중앙거리 344-65 (정순장김마을)', 'phone': '011-479-2175'}
# {'id': 3, 'name': '이지연', 'email': 'subin59@example.net', 'address': '대구광역시 북구 서초중앙4가 456-34 (옥순김면)', 'phone': '062-502-6966'}
# {'id': 4, 'name': '김미정', 'email': 'gimareum@example.net', 'address': '울산광역시 성동구 선릉가 56 (미숙심권면)', 'phone': '053-790-9231'}
# {'id': 5, 'name': '이종수', 'email': 'jeongnami@example.net', 'address': '인천광역시 동작구 삼성807길 739', 'phone': '033-932-6909'}
# {'id': 6, 'name': '이미정', 'email': 'jeongsig76@example.com', 'address': '부산광역시 송파구 백제고분2가 378-42', 'phone': '061-699-9214'}
# {'id': 7, 'name': '문선영', 'email': 'seojuni@example.com', 'address': '대전광역시 마포구 석촌호수11가 111 (정호이읍)', 'phone': '041-921-0822'}
# {'id': 8, 'name': '이옥자', 'email': 'mgim@example.net', 'address': '서울특별시 송파구 영동대28로 97 (민지이읍)', 'phone': '011-785-1458'}
# {'id': 9, 'name': '손서영', 'email': 'hongjia@example.org', 'address': '서울특별시 용산구 역삼6길 지하192 (정자김읍)', 'phone': '044-747-6046'}
# {'id': 10, 'name': '권예원', 'email': 'yeongsug55@example.net', 'address': '서울특별시 동대문구 선릉61로 575-96', 'phone': '017-304-3063'}
# {'id': 11, 'name': '이미영', 'email': 'hayungim@example.com', 'address': '전라북도 삼척시 가락거리 지하622 (지우이최마을)', 'phone': '042-903-2439'}
# {'id': 12, 'name': '박현우', 'email': 'hgim@example.com', 'address': '인천광역시 양천구 가락길 697', 'phone': '018-581-2118'}
# {'id': 13, 'name': '장보람', 'email': 'iseonghyeon@example.net', 'address': '충청북도 수원시 영통구 양재천길 350', 'phone': '033-942-5347'}
# {'id': 14, 'name': '박민재', 'email': 'songjeongsug@example.com', 'address': '강원도 광주시 오금540가 490', 'phone': '055-312-6546'}
# {'id': 15, 'name': '이광수', 'email': 'seoyunheo@example.org', 'address': '충청남도 안양시 만안구 강남대로 235', 'phone': '031-401-2995'}
# {'id': 16, 'name': '이도윤', 'email': 'ijiyeong@example.com', 'address': '경상남도 김포시 양재천거리 51-42', 'phone': '02-0729-9565'}
# {'id': 17, 'name': '박영식', 'email': 'hayun58@example.net', 'address': '충청남도 고양시 덕양구 석촌호수거리 221', 'phone': '031-426-1420'}
# {'id': 18, 'name': '안영진', 'email': 'jihyegim@example.net', 'address': '부산광역시 동구 학동가 지하622 (정호최최읍)', 'phone': '041-561-6932'}
# {'id': 19, 'name': '심영호', 'email': 'dohyeon39@example.org', 'address': '광주광역시 동작구 강남대797로 493', 'phone': '032-438-5633'}
# {'id': 20, 'name': '김도윤', 'email': 'yejun79@example.net', 'address': '울산광역시 동구 서초대거리 138', 'phone': '064-708-4475'}
# {'id': 21, 'name': '김은서', 'email': 'seongsubag@example.org', 'address': '전라북도 안양시 가락925거리 213-17', 'phone': '016-376-9429'}
# {'id': 22, 'name': '이지연', 'email': 'jiagim@example.net', 'address': '광주광역시 마포구 양재천가 641-97 (은주최동)', 'phone': '062-160-0298'}
# {'id': 23, 'name': '최성진', 'email': 'zi@example.com', 'address': '전라남도 이천시 석촌호수가 지하526', 'phone': '052-014-1459'}
# {'id': 24, 'name': '이동현', 'email': 'yejungo@example.org', 'address': '제주특별자치도 수원시 팔달구 강남대0길 935-64', 'phone': '010-6758-9009'}
# {'id': 25, 'name': '김도윤', 'email': 'seongmini@example.com', 'address': '울산광역시 영등포구 양재천로 259 (정수김동)', 'phone': '019-263-3223'}
# {'id': 26, 'name': '김순옥', 'email': 'gimsunog@example.org', 'address': '강원도 용인시 기흥구 강남대거리 371', 'phone': '051-251-5986'}
# {'id': 27, 'name': '박하은', 'email': 'eunjeong96@example.net', 'address': '경상북도 청주시 흥덕구 반포대로 614 (민지김김동)', 'phone': '011-378-3435'}
# {'id': 28, 'name': '이승민', 'email': 'sangceolsong@example.org', 'address': '전라북도 안성시 개포47로 542', 'phone': '031-568-8788'}
# {'id': 29, 'name': '김지영', 'email': 'borami@example.com', 'address': '울산광역시 노원구 잠실35가 579-13 (재현이마을)', 'phone': '054-649-6822'}
# {'id': 30, 'name': '전지후', 'email': 'boram45@example.org', 'address': '강원도 의정부시 역삼로 593 (현준김마을)', 'phone': '070-5716-3713'}
# {'id': 31, 'name': '김미영', 'email': 'zi@example.net', 'address': '대구광역시 성북구 강남대길 209', 'phone': '064-766-4753'}
# {'id': 32, 'name': '김민재', 'email': 'dohyeon91@example.org', 'address': '전라북도 양평군 서초중앙473로 241-70 (순자홍동)', 'phone': '033-859-4447'}
# {'id': 33, 'name': '류정웅', 'email': 'subingim@example.org', 'address': '충청북도 논산시 개포71거리 426', 'phone': '051-389-4352'}
# {'id': 34, 'name': '문성현', 'email': 'jhan@example.net', 'address': '충청남도 안양시 압구정744로 261 (영식강동)', 'phone': '011-720-6766'}
# {'id': 35, 'name': '김재호', 'email': 'jeongsug68@example.net', 'address': '대구광역시 서초구 개포406길 153 (민수이읍)', 'phone': '017-281-3692'}
# {'id': 36, 'name': '김성훈', 'email': 'jeongsug12@example.org', 'address': '세종특별자치시 영등포구 가락길 462 (영수김서읍)', 'phone': '031-468-3730'}
# {'id': 37, 'name': '김성수', 'email': 'jeonghunyun@example.org', 'address': '충청남도 광주시 백제고분9길 978', 'phone': '052-727-8715'}
# {'id': 38, 'name': '김준영', 'email': 'heobyeongceol@example.org', 'address': '울산광역시 성북구 서초중앙거리 923-36 (예지김박면)', 'phone': '064-777-3321'}
# {'id': 39, 'name': '강민수', 'email': 'hwangjiyeon@example.net', 'address': '부산광역시 중랑구 양재천길 440-53 (영환박리)', 'phone': '053-851-2907'}
# {'id': 40, 'name': '최병철', 'email': 'ogsungim@example.com', 'address': '부산광역시 성동구 서초대로 969 (옥순서엄면)', 'phone': '032-554-9525'}
# {'id': 41, 'name': '김지은', 'email': 'ccoe@example.com', 'address': '제주특별자치도 단양군 봉은사45길 564-12 (명숙진김동)', 'phone': '018-729-8107'}
# {'id': 42, 'name': '김수민', 'email': 'jiminyun@example.net', 'address': '울산광역시 성동구 압구정860가 402-12 (보람이동)', 'phone': '019-464-3977'}
# {'id': 43, 'name': '김경숙', 'email': 'sunog40@example.net', 'address': '인천광역시 성동구 삼성149로 487', 'phone': '016-501-5600'}
# {'id': 44, 'name': '이서연', 'email': 'bagyejin@example.net', 'address': '전라남도 천안시 서북구 오금142길 282-14 (수빈최장면)', 'phone': '032-198-4006'}
# {'id': 45, 'name': '전서준', 'email': 'acoe@example.org', 'address': '경상북도 횡성군 양재천73길 953', 'phone': '062-900-2783'}
# {'id': 46, 'name': '홍정숙', 'email': 'yeongsun62@example.com', 'address': '경상북도 용인시 처인구 언주길 910', 'phone': '031-029-2826'}
# {'id': 47, 'name': '김성현', 'email': 'seonghun63@example.net', 'address': '전라남도 예산군 강남대로 95', 'phone': '017-703-2693'}
# {'id': 48, 'name': '김정남', 'email': 'iyeongho@example.net', 'address': '광주광역시 동작구 언주가 418', 'phone': '054-034-9166'}
# {'id': 49, 'name': '김지영', 'email': 'myeongjagang@example.org', 'address': '제주특별자치도 속초시 압구정107가 지하749', 'phone': '053-147-5836'}
# {'id': 50, 'name': '장명자', 'email': 'eunjeong88@example.org', 'address': '제주특별자치도 과천시 역삼로 480-73', 'phone': '018-051-4225'}
# {'id': 51, 'name': '문현지', 'email': 'gimhyeonjun@example.net', 'address': '울산광역시 구로구 테헤란895길 600-96', 'phone': '051-745-2064'}
# {'id': 52, 'name': '송정훈', 'email': 'wi@example.com', 'address': '인천광역시 중구 언주4로 827', 'phone': '019-250-1303'}
# {'id': 53, 'name': '배정숙', 'email': 'sanghuni@example.org', 'address': '전라북도 안산시 상록구 오금656가 18', 'phone': '017-136-2873'}
# {'id': 54, 'name': '김승민', 'email': 'coeeunseo@example.org', 'address': '경기도 성남시 중원구 도산대거리 954-84', 'phone': '033-678-0904'}
# {'id': 55, 'name': '이민재', 'email': 'myeongsuggim@example.org', 'address': '울산광역시 종로구 가락로 490 (중수김김동)', 'phone': '011-391-5336'}
# {'id': 56, 'name': '김하윤', 'email': 'gyeongsuggim@example.com', 'address': '강원도 용인시 압구정11길 298', 'phone': '053-165-4511'}
# {'id': 57, 'name': '김병철', 'email': 'baghyeonji@example.com', 'address': '부산광역시 강동구 삼성길 911-32 (성현김김면)', 'phone': '055-772-6067'}
# {'id': 58, 'name': '김준영', 'email': 'hyeonju56@example.net', 'address': '부산광역시 영등포구 압구정92거리 924', 'phone': '052-854-5824'}
# {'id': 59, 'name': '민윤서', 'email': 'ojeongsig@example.net', 'address': '경상남도 수원시 장안구 개포78길 991 (상훈고안마을)', 'phone': '051-014-9796'}
# {'id': 60, 'name': '신성수', 'email': 'yunseoi@example.net', 'address': '경상남도 용인시 수지구 삼성거리 29', 'phone': '064-767-7352'}
# {'id': 61, 'name': '최중수', 'email': 'jaehyeon73@example.net', 'address': '경상남도 안양시 동안구 석촌호수0거리 823-96', 'phone': '055-751-4766'}
# {'id': 62, 'name': '김보람', 'email': 'bagyeji@example.org', 'address': '부산광역시 강남구 서초대10길 298-37', 'phone': '064-737-5702'}
# {'id': 63, 'name': '이재호', 'email': 'zi@example.net', 'address': '서울특별시 강동구 반포대3거리 951-76 (아름김마을)', 'phone': '061-356-1662'}
# {'id': 64, 'name': '김영자', 'email': 'jeongsun84@example.com', 'address': '부산광역시 중구 백제고분길 지하464 (서윤김이면)', 'phone': '042-167-4484'}
# {'id': 65, 'name': '권경희', 'email': 'jeongnam80@example.org', 'address': '대전광역시 남구 서초대41가 635', 'phone': '02-6522-2455'}
# {'id': 66, 'name': '이진호', 'email': 'ui@example.org', 'address': '경상북도 삼척시 삼성1로 614 (도현이리)', 'phone': '019-685-3433'}
# {'id': 67, 'name': '김은주', 'email': 'yeonggilcoe@example.org', 'address': '경상북도 의정부시 백제고분614로 147 (은정김동)', 'phone': '043-633-0948'}
# {'id': 68, 'name': '김옥자', 'email': 'ijuweon@example.org', 'address': '제주특별자치도 아산시 역삼길 881-32 (영희홍이마을)', 'phone': '011-023-5987'}
# {'id': 69, 'name': '김진우', 'email': 'songjiweon@example.net', 'address': '경상북도 천안시 동남구 영동대길 963-1', 'phone': '051-145-9032'}
# {'id': 70, 'name': '손준혁', 'email': 'pgim@example.net', 'address': '세종특별자치시 성동구 학동가 지하922', 'phone': '054-576-4205'}
# {'id': 71, 'name': '김숙자', 'email': 'keom@example.net', 'address': '충청남도 청주시 서원구 선릉99길 947 (건우남김면)', 'phone': '02-0990-3910'}
# {'id': 72, 'name': '진정수', 'email': 'seojeonghun@example.net', 'address': '광주광역시 구로구 서초중앙48로 433 (순자오면)', 'phone': '054-343-1103'}
# {'id': 73, 'name': '이지혜', 'email': 'sanghyeoncoe@example.com', 'address': '대구광역시 중구 삼성5로 지하596 (예은김면)', 'phone': '02-5627-6673'}
# {'id': 74, 'name': '박서연', 'email': 'jeongnamyu@example.org', 'address': '전라남도 단양군 백제고분거리 905', 'phone': '033-920-3916'}
# {'id': 75, 'name': '서영환', 'email': 'gimjaeho@example.org', 'address': '경상남도 화천군 석촌호수가 659', 'phone': '043-273-4993'}
# {'id': 76, 'name': '김종수', 'email': 'jeongsugi@example.org', 'address': '제주특별자치도 화천군 학동거리 265 (민준이김리)', 'phone': '055-367-4764'}
# {'id': 77, 'name': '이민준', 'email': 'mgim@example.org', 'address': '울산광역시 동대문구 가락23거리 929-68 (하윤김권면)', 'phone': '052-807-5808'}
# {'id': 78, 'name': '서지은', 'email': 'gweoneungyeong@example.com', 'address': '전라북도 옥천군 석촌호수로 지하85', 'phone': '032-906-8245'}
# {'id': 79, 'name': '류지후', 'email': 'miyeong80@example.com', 'address': '경기도 안산시 상록구 논현715거리 569', 'phone': '052-849-8549'}
# {'id': 80, 'name': '윤지훈', 'email': 'rgim@example.net', 'address': '대전광역시 광진구 언주337길 319-27 (하윤임박읍)', 'phone': '010-8251-2438'}
# {'id': 81, 'name': '김지아', 'email': 'hayuni@example.com', 'address': '인천광역시 영등포구 영동대거리 645-96 (영순주면)', 'phone': '032-707-4679'}
# {'id': 82, 'name': '홍경숙', 'email': 'bagjieun@example.net', 'address': '부산광역시 성북구 선릉거리 81-19 (정수서동)', 'phone': '055-041-4188'}
# {'id': 83, 'name': '김미영', 'email': 'eunjian@example.org', 'address': '전라남도 구리시 오금거리 168', 'phone': '064-704-4821'}
# {'id': 84, 'name': '주옥순', 'email': 'ogsunbag@example.net', 'address': '서울특별시 구로구 역삼26가 75 (정웅한안면)', 'phone': '041-215-3762'}
# {'id': 85, 'name': '최춘자', 'email': 'noyeonggil@example.com', 'address': '울산광역시 성북구 서초대가 709 (지아김리)', 'phone': '017-131-2050'}
# {'id': 86, 'name': '강상현', 'email': 'jeongsu56@example.net', 'address': '경기도 고양시 덕양구 도산대92길 지하549', 'phone': '051-202-9313'}
# {'id': 87, 'name': '이아름', 'email': 'yunjihun@example.net', 'address': '대전광역시 마포구 강남대거리 419 (보람백리)', 'phone': '062-692-7690'}
# {'id': 88, 'name': '황지훈', 'email': 'sanghyeon73@example.org', 'address': '대구광역시 강서구 강남대가 103', 'phone': '051-079-8582'}
# {'id': 89, 'name': '박영식', 'email': 'seojiyeon@example.org', 'address': '충청북도 홍성군 양재천로 222', 'phone': '031-999-9303'}
# {'id': 90, 'name': '김은지', 'email': 'dgim@example.org', 'address': '전라북도 안산시 개포길 78-89 (영미안김리)', 'phone': '052-114-7925'}
# {'id': 91, 'name': '권건우', 'email': 'yeonggil17@example.net', 'address': '전라북도 성남시 중원구 영동대016거리 855', 'phone': '033-153-6822'}
# {'id': 92, 'name': '권성수', 'email': 'gson@example.org', 'address': '제주특별자치도 청주시 청원구 선릉가 66', 'phone': '055-905-7266'}
# {'id': 93, 'name': '김민준', 'email': 'hyeonsug62@example.org', 'address': '서울특별시 동작구 양재천거리 510-21', 'phone': '016-524-3022'}
# {'id': 94, 'name': '박순옥', 'email': 'minji78@example.com', 'address': '강원도 양구군 언주가 969', 'phone': '019-511-5483'}
# {'id': 95, 'name': '최지현', 'email': 'mi@example.org', 'address': '강원도 보령시 반포대0로 584-2 (미영윤이면)', 'phone': '017-191-6310'}
# {'id': 96, 'name': '박윤서', 'email': 'gweonseoyun@example.net', 'address': '전라남도 서산시 도산대거리 251 (진우권이마을)', 'phone': '043-482-2626'}
# {'id': 97, 'name': '권예지', 'email': 'simjeongsig@example.org', 'address': '경기도 음성군 강남대5로 236', 'phone': '010-3242-8565'}
# {'id': 98, 'name': '장옥순', 'email': 'bagmiyeong@example.org', 'address': '충청북도 괴산군 논현365거리 70 (중수김권읍)', 'phone': '055-402-9858'}
# {'id': 99, 'name': '신영환', 'email': 'jeongsun86@example.net', 'address': '충청북도 청주시 흥덕구 오금길 606-1 (민지백김리)', 'phone': '018-272-4403'}
# {'id': 100, 'name': '성종수', 'email': 'eunyeong51@example.com', 'address': '충청북도 안산시 상록구 가락거리 지하186', 'phone': '054-747-0809'}
# {'id': 101, 'name': '남서준', 'email': 'bagmijeong@example.org', 'address': '세종특별자치시 북구 논현4로 274-73', 'phone': '041-566-3153'}
# {'id': 102, 'name': '이정호', 'email': 'zgim@example.com', 'address': '경상북도 양평군 압구정길 586 (미경서이리)', 'phone': '043-279-9131'}
# {'id': 103, 'name': '김성수', 'email': 'sujini@example.com', 'address': '울산광역시 강서구 서초대976길 799', 'phone': '044-208-6259'}
# {'id': 104, 'name': '이명자', 'email': 'seonyeonggim@example.org', 'address': '서울특별시 종로구 삼성가 651-56', 'phone': '054-253-4261'}
# {'id': 105, 'name': '김선영', 'email': 'suminhong@example.net', 'address': '전라북도 괴산군 선릉가 565', 'phone': '053-990-3473'}
# {'id': 106, 'name': '이정웅', 'email': 'gimjeongja@example.org', 'address': '인천광역시 강서구 잠실가 885-70 (정순안마을)', 'phone': '032-186-0459'}
# {'id': 107, 'name': '김상훈', 'email': 'sonsangho@example.net', 'address': '울산광역시 관악구 압구정길 595-27', 'phone': '070-5501-1103'}
# {'id': 108, 'name': '박채원', 'email': 'yeji47@example.net', 'address': '경상북도 천안시 동남구 논현92로 730', 'phone': '051-148-5389'}
# {'id': 109, 'name': '강순자', 'email': 'li@example.org', 'address': '경상북도 수원시 강남대거리 250-68', 'phone': '016-858-7435'}
# {'id': 110, 'name': '박정수', 'email': 'wan@example.net', 'address': '대구광역시 양천구 삼성길 436', 'phone': '064-710-4862'}
# {'id': 111, 'name': '김영자', 'email': 'imisug@example.com', 'address': '대구광역시 양천구 오금길 897-10', 'phone': '053-443-8419'}
# {'id': 112, 'name': '이주원', 'email': 'geonu81@example.net', 'address': '광주광역시 동구 테헤란가 263 (지우장이동)', 'phone': '054-323-4179'}
# {'id': 113, 'name': '김정호', 'email': 'oyunseo@example.org', 'address': '울산광역시 광진구 오금거리 336', 'phone': '044-180-8380'}
# {'id': 114, 'name': '최옥자', 'email': 'caeweon99@example.net', 'address': '부산광역시 은평구 서초대거리 898-41 (정남이읍)', 'phone': '064-721-4966'}
# {'id': 115, 'name': '배승민', 'email': 'yuyeonggil@example.org', 'address': '충청북도 수원시 팔달구 서초대755거리 지하659', 'phone': '033-058-1573'}
# {'id': 116, 'name': '최하은', 'email': 'areum03@example.net', 'address': '부산광역시 서초구 서초중앙057거리 477 (지민김박면)', 'phone': '063-906-9380'}
# {'id': 117, 'name': '김성진', 'email': 'kbag@example.net', 'address': '전라북도 논산시 잠실거리 694-25 (지우한마을)', 'phone': '017-233-9704'}
# {'id': 118, 'name': '박영식', 'email': 'jiweoni@example.org', 'address': '경기도 의왕시 봉은사가 지하358', 'phone': '064-796-6363'}
# {'id': 119, 'name': '김민재', 'email': 'hwangeunyeong@example.com', 'address': '부산광역시 중랑구 삼성로 808-50', 'phone': '062-051-3974'}
# {'id': 120, 'name': '박준영', 'email': 'hhan@example.org', 'address': '경상남도 태안군 석촌호수0길 696', 'phone': '010-7567-7497'}
# {'id': 121, 'name': '김중수', 'email': 'junyeong56@example.net', 'address': '서울특별시 종로구 개포2길 271 (상호장김리)', 'phone': '063-053-2807'}
# {'id': 122, 'name': '최경희', 'email': 'gimjungsu@example.net', 'address': '전라북도 평택시 테헤란로 561-51 (정호김이읍)', 'phone': '051-334-2600'}
# {'id': 123, 'name': '김영숙', 'email': 'jeonghobag@example.com', 'address': '제주특별자치도 고성군 봉은사11로 767-45 (도윤이읍)', 'phone': '064-794-0907'}
# {'id': 124, 'name': '권현준', 'email': 'seoyunheo@example.net', 'address': '대구광역시 동대문구 서초대가 251-25 (은지김김리)', 'phone': '043-934-7122'}
# {'id': 125, 'name': '홍상훈', 'email': 'kgim@example.net', 'address': '경상남도 하남시 학동길 263', 'phone': '032-688-1312'}
# {'id': 126, 'name': '이민준', 'email': 'jeongjason@example.com', 'address': '경상남도 수원시 권선구 도산대가 694-20 (정희이김면)', 'phone': '055-841-0877'}
# {'id': 127, 'name': '이성현', 'email': 'yeongmi58@example.com', 'address': '대전광역시 금천구 오금거리 145', 'phone': '016-713-8431'}
# {'id': 128, 'name': '이예원', 'email': 'myeongsuggim@example.com', 'address': '경상남도 예산군 압구정로 230-74', 'phone': '042-471-5728'}
# {'id': 129, 'name': '이동현', 'email': 'goujin@example.net', 'address': '강원도 과천시 백제고분로 810', 'phone': '044-409-7115'}
# {'id': 130, 'name': '김현준', 'email': 'bagjeonghyi@example.org', 'address': '충청남도 제천시 테헤란203길 694', 'phone': '016-140-4389'}
# {'id': 131, 'name': '이하윤', 'email': 'songyeongja@example.net', 'address': '경상남도 계룡시 학동거리 197', 'phone': '042-651-4644'}
# {'id': 132, 'name': '고민지', 'email': 'songwangsu@example.org', 'address': '대전광역시 노원구 오금13길 593 (영수이윤마을)', 'phone': '052-316-9347'}
# {'id': 133, 'name': '김정수', 'email': 'yeji76@example.com', 'address': '강원도 제천시 양재천10가 936-43', 'phone': '033-494-2484'}
# {'id': 134, 'name': '박건우', 'email': 'gweonjunyeong@example.org', 'address': '경상북도 동해시 언주23로 224', 'phone': '043-926-8033'}
# {'id': 135, 'name': '김서연', 'email': 'gimseungmin@example.net', 'address': '전라남도 양양군 영동대418가 545 (영진김민읍)', 'phone': '044-901-5572'}
# {'id': 136, 'name': '최영미', 'email': 'seonyeonggim@example.com', 'address': '충청남도 성남시 분당구 양재천5가 지하96 (지훈강읍)', 'phone': '053-292-1784'}
# {'id': 137, 'name': '박민석', 'email': 'junhosim@example.net', 'address': '대구광역시 도봉구 가락길 971-60', 'phone': '051-819-9764'}
# {'id': 138, 'name': '윤영호', 'email': 'ijeongung@example.com', 'address': '서울특별시 종로구 학동8길 315-60', 'phone': '010-3112-7185'}
# {'id': 139, 'name': '김정수', 'email': 'jiweon37@example.net', 'address': '대구광역시 서구 영동대가 644 (지영박동)', 'phone': '055-838-1848'}
# {'id': 140, 'name': '김종수', 'email': 'kbag@example.net', 'address': '전라남도 부천시 반포대4길 269-1 (서현김동)', 'phone': '053-309-1102'}
# {'id': 141, 'name': '김정수', 'email': 'sunoggu@example.com', 'address': '경상남도 인제군 언주로 87', 'phone': '033-206-8823'}
# {'id': 142, 'name': '이예원', 'email': 'sangceol01@example.org', 'address': '부산광역시 관악구 석촌호수로 978', 'phone': '053-870-4681'}
# {'id': 143, 'name': '박지후', 'email': 'yeongsugi@example.net', 'address': '대구광역시 서초구 영동대가 773 (선영김마을)', 'phone': '033-836-3030'}
# {'id': 144, 'name': '김성현', 'email': 'hsong@example.net', 'address': '경상남도 안양시 도산대거리 지하937 (주원박읍)', 'phone': '017-361-2702'}
# {'id': 145, 'name': '서지민', 'email': 'sujin28@example.com', 'address': '부산광역시 동구 삼성3길 48-45', 'phone': '02-6325-5113'}
# {'id': 146, 'name': '김영자', 'email': 'jangyeeun@example.org', 'address': '충청북도 광주시 반포대로 298-71 (선영류마을)', 'phone': '041-066-8363'}
# {'id': 147, 'name': '유미영', 'email': 'jangsunog@example.com', 'address': '강원도 동두천시 논현길 650 (영식이고동)', 'phone': '041-819-1946'}
# {'id': 148, 'name': '김주원', 'email': 'iminjun@example.org', 'address': '울산광역시 중구 양재천로 568 (은경손박동)', 'phone': '070-5903-8268'}
# {'id': 149, 'name': '권성진', 'email': 'di@example.com', 'address': '강원도 인제군 압구정로 970-11 (예원윤송면)', 'phone': '010-7257-9509'}
# {'id': 150, 'name': '이광수', 'email': 'bmun@example.org', 'address': '대구광역시 강남구 역삼13로 906 (현숙최박리)', 'phone': '051-213-5995'}
# {'id': 151, 'name': '황경수', 'email': 'bgim@example.net', 'address': '제주특별자치도 오산시 가락길 864 (지후조장동)', 'phone': '061-088-8634'}
# {'id': 152, 'name': '김지아', 'email': 'seojongsu@example.com', 'address': '부산광역시 구로구 개포86로 865', 'phone': '052-575-6267'}
# {'id': 153, 'name': '황수진', 'email': 'simseongsu@example.org', 'address': '광주광역시 영등포구 봉은사144가 340-64', 'phone': '019-424-9972'}
# {'id': 154, 'name': '이민재', 'email': 'yunhyeonji@example.com', 'address': '부산광역시 강북구 잠실083길 692 (현준신리)', 'phone': '016-626-1384'}
# {'id': 155, 'name': '고중수', 'email': 'ieunjeong@example.com', 'address': '인천광역시 동대문구 백제고분길 323-48 (민지김김마을)', 'phone': '02-7614-8348'}
# {'id': 156, 'name': '한현준', 'email': 'si@example.net', 'address': '대구광역시 강동구 양재천580거리 576 (성현이이동)', 'phone': '019-033-2809'}
# {'id': 157, 'name': '장예지', 'email': 'hansanghun@example.net', 'address': '충청북도 용인시 수지구 역삼가 237', 'phone': '02-6687-0315'}
# {'id': 158, 'name': '이성수', 'email': 'agim@example.net', 'address': '인천광역시 서구 영동대5길 85', 'phone': '063-499-9604'}
# {'id': 159, 'name': '최준서', 'email': 'ieungyeong@example.net', 'address': '부산광역시 관악구 봉은사503가 262', 'phone': '016-452-7199'}
# {'id': 160, 'name': '김승민', 'email': 'lsin@example.com', 'address': '경상북도 양구군 테헤란로 88 (하은하리)', 'phone': '063-879-5417'}
# {'id': 161, 'name': '이진호', 'email': 'oi@example.net', 'address': '경기도 동해시 백제고분590거리 450-38 (명숙김허리)', 'phone': '064-757-4583'}
# {'id': 162, 'name': '오승민', 'email': 'qgim@example.com', 'address': '경상남도 음성군 강남대17가 640-21 (정자이동)', 'phone': '054-966-0896'}
# {'id': 163, 'name': '김우진', 'email': 'misug06@example.org', 'address': '강원도 광명시 테헤란242로 624-50 (보람김김마을)', 'phone': '062-735-8163'}
# {'id': 164, 'name': '황진호', 'email': 'jeongsugo@example.org', 'address': '제주특별자치도 진천군 언주33로 지하637 (시우박읍)', 'phone': '052-510-8524'}
# {'id': 165, 'name': '박상현', 'email': 'seunghyeon28@example.net', 'address': '경기도 김포시 백제고분길 760-78 (춘자안이동)', 'phone': '02-5236-0272'}
# {'id': 166, 'name': '김현우', 'email': 'siujeong@example.net', 'address': '인천광역시 영등포구 도산대029로 117', 'phone': '063-349-0515'}
# {'id': 167, 'name': '이지영', 'email': 'ggim@example.net', 'address': '대구광역시 양천구 영동대436거리 914', 'phone': '017-835-9188'}
# {'id': 168, 'name': '김민석', 'email': 'nbag@example.org', 'address': '대구광역시 중구 영동대93거리 83-72 (진우안박읍)', 'phone': '063-828-9039'}
# {'id': 169, 'name': '김지연', 'email': 'jeongho17@example.org', 'address': '전라남도 고양시 언주로 581-66 (영순오김동)', 'phone': '018-315-1864'}
# {'id': 170, 'name': '김지후', 'email': 'isumin@example.org', 'address': '전라북도 과천시 백제고분로 151', 'phone': '051-609-3747'}
# {'id': 171, 'name': '박영식', 'email': 'cgim@example.org', 'address': '전라남도 청주시 서원구 선릉6거리 509', 'phone': '018-571-8376'}
# {'id': 172, 'name': '김정자', 'email': 'eunseo71@example.org', 'address': '부산광역시 서구 압구정076거리 707-75 (정훈김민리)', 'phone': '031-710-7899'}
# {'id': 173, 'name': '김보람', 'email': 'yeongceolmun@example.com', 'address': '강원도 안성시 서초중앙0로 550 (춘자김읍)', 'phone': '032-447-8630'}
# {'id': 174, 'name': '김현주', 'email': 'yeongsungim@example.org', 'address': '전라남도 안산시 반포대거리 913-27 (하은이면)', 'phone': '055-094-7131'}
# {'id': 175, 'name': '류영수', 'email': 'gwagminjun@example.org', 'address': '부산광역시 남구 강남대9가 257-88', 'phone': '017-967-1353'}
# {'id': 176, 'name': '박수민', 'email': 'sugja32@example.org', 'address': '세종특별자치시 노원구 선릉로 856-60 (숙자강송마을)', 'phone': '010-8921-3503'}
# {'id': 177, 'name': '차숙자', 'email': 'uboram@example.net', 'address': '대전광역시 중구 논현거리 15', 'phone': '018-783-6807'}
# {'id': 178, 'name': '황미영', 'email': 'misug01@example.net', 'address': '제주특별자치도 수원시 백제고분가 652 (정훈홍송면)', 'phone': '017-951-0834'}
# {'id': 179, 'name': '윤지은', 'email': 'gyeongsu71@example.org', 'address': '세종특별자치시 관악구 오금96가 355 (현우안김마을)', 'phone': '033-760-2273'}
# {'id': 180, 'name': '이영순', 'email': 'jihyeon18@example.org', 'address': '서울특별시 용산구 영동대5가 606', 'phone': '043-929-5775'}
# {'id': 181, 'name': '이상훈', 'email': 'tryu@example.com', 'address': '서울특별시 동작구 논현09길 725', 'phone': '019-772-2809'}
# {'id': 182, 'name': '송지은', 'email': 'yejun20@example.com', 'address': '울산광역시 중구 석촌호수거리 지하392 (성민안면)', 'phone': '055-014-0723'}
# {'id': 183, 'name': '김정훈', 'email': 'jangjiu@example.net', 'address': '경기도 제천시 서초중앙8길 383-99', 'phone': '055-912-1255'}
# {'id': 184, 'name': '김수진', 'email': 'seongmin06@example.net', 'address': '충청남도 고양시 양재천75거리 724-99', 'phone': '064-790-7671'}
# {'id': 185, 'name': '김선영', 'email': 'yejingweon@example.com', 'address': '서울특별시 관악구 잠실로 822 (혜진이리)', 'phone': '016-337-6133'}
# {'id': 186, 'name': '최춘자', 'email': 'sangceol49@example.org', 'address': '전라남도 공주시 선릉77거리 지하750 (도현한마을)', 'phone': '031-093-5932'}
# {'id': 187, 'name': '김중수', 'email': 'iyeongja@example.org', 'address': '경상북도 부천시 소사구 테헤란길 695-61 (민수김리)', 'phone': '02-6040-7897'}
# {'id': 188, 'name': '오현준', 'email': 'gujihun@example.net', 'address': '전라북도 과천시 역삼길 지하934', 'phone': '019-751-2269'}
# {'id': 189, 'name': '윤순자', 'email': 'siubag@example.com', 'address': '인천광역시 영등포구 강남대로 지하100 (하은한읍)', 'phone': '017-943-6245'}
# {'id': 190, 'name': '차현정', 'email': 'seohyeon33@example.net', 'address': '전라북도 금산군 반포대거리 지하915 (성민이양리)', 'phone': '053-297-5484'}
# {'id': 191, 'name': '양상현', 'email': 'boram64@example.net', 'address': '서울특별시 구로구 개포가 37-28', 'phone': '010-6073-5363'}
# {'id': 192, 'name': '배영자', 'email': 'bagjeongung@example.net', 'address': '울산광역시 노원구 봉은사길 855', 'phone': '016-830-2434'}
# {'id': 193, 'name': '오재호', 'email': 'fgim@example.org', 'address': '대전광역시 강서구 역삼19로 818', 'phone': '019-990-5216'}
# {'id': 194, 'name': '나예은', 'email': 'jeongsig37@example.net', 'address': '인천광역시 노원구 테헤란거리 182 (선영차김동)', 'phone': '011-616-1837'}
# {'id': 195, 'name': '장은경', 'email': 'jaeho94@example.com', 'address': '인천광역시 강서구 봉은사121거리 341-7 (미영류마을)', 'phone': '042-823-8180'}
# {'id': 196, 'name': '서은영', 'email': 'coeyeeun@example.org', 'address': '제주특별자치도 동해시 서초대051가 742-58', 'phone': '031-386-1921'}
# {'id': 197, 'name': '김준영', 'email': 'yejun01@example.com', 'address': '충청남도 이천시 개포길 589 (현숙최윤동)', 'phone': '063-402-0202'}
# {'id': 198, 'name': '이미숙', 'email': 'junhyeog01@example.com', 'address': '제주특별자치도 공주시 영동대84거리 876-3 (숙자김김마을)', 'phone': '051-147-8403'}
# {'id': 199, 'name': '양영호', 'email': 'iyeongsu@example.com', 'address': '광주광역시 구로구 테헤란로 926', 'phone': '051-319-9071'}
# {'id': 200, 'name': '김영진', 'email': 'hyejinyu@example.com', 'address': '충청북도 청주시 서원구 개포4가 540-2 (영숙김리)', 'phone': '052-986-6510'}
# {'id': 201, 'name': '최순자', 'email': 'kgim@example.net', 'address': '울산광역시 동작구 삼성로 595-9 (하윤윤전리)', 'phone': '061-277-0628'}
# {'id': 202, 'name': '이현준', 'email': 'eungyeong64@example.net', 'address': '대전광역시 동대문구 잠실로 278-68 (현지이조리)', 'phone': '051-896-0297'}
# {'id': 203, 'name': '이정웅', 'email': 'minjigim@example.net', 'address': '경기도 단양군 개포896가 486 (윤서김장리)', 'phone': '055-004-1370'}
# {'id': 204, 'name': '최은서', 'email': 'obag@example.org', 'address': '전라북도 양평군 서초대거리 지하49 (미정김마을)', 'phone': '064-727-2682'}
# {'id': 205, 'name': '최정식', 'email': 'hyeonjii@example.org', 'address': '경상남도 고성군 개포69거리 733-77', 'phone': '011-394-3449'}
# {'id': 206, 'name': '김유진', 'email': 'bagyeongsun@example.com', 'address': '경상남도 평택시 오금가 47', 'phone': '062-420-4250'}
# {'id': 207, 'name': '김현준', 'email': 'bagsujin@example.com', 'address': '경상남도 청양군 오금769가 8-56 (민수김마을)', 'phone': '052-048-4375'}
# {'id': 208, 'name': '최정훈', 'email': 'pgim@example.net', 'address': '제주특별자치도 안양시 강남대거리 지하687', 'phone': '052-856-1469'}
# {'id': 209, 'name': '최영희', 'email': 'bagseoyeong@example.com', 'address': '울산광역시 노원구 역삼2길 165-3', 'phone': '054-035-1556'}
# {'id': 210, 'name': '이성호', 'email': 'gimjeonghyi@example.org', 'address': '서울특별시 서대문구 학동가 436', 'phone': '043-513-9708'}
# {'id': 211, 'name': '이영호', 'email': 'ubag@example.org', 'address': '세종특별자치시 강동구 봉은사721가 926', 'phone': '051-204-2458'}
# {'id': 212, 'name': '김예지', 'email': 'yunseo09@example.com', 'address': '강원도 춘천시 논현81가 214', 'phone': '052-469-8960'}
# {'id': 213, 'name': '김영환', 'email': 'yeongja31@example.org', 'address': '전라북도 보은군 서초중앙로 970 (지훈최마을)', 'phone': '053-603-7413'}
# {'id': 214, 'name': '최은지', 'email': 'hyeonjii@example.org', 'address': '경상남도 부천시 도산대로 103-43 (도윤배리)', 'phone': '032-133-1585'}
# {'id': 215, 'name': '이춘자', 'email': 'minsuju@example.org', 'address': '서울특별시 관악구 논현908로 812', 'phone': '032-343-2738'}
# {'id': 216, 'name': '최지원', 'email': 'djeong@example.net', 'address': '대구광역시 중랑구 양재천84로 675-74', 'phone': '011-744-8119'}
# {'id': 217, 'name': '백성훈', 'email': 'oyun@example.net', 'address': '인천광역시 남구 반포대302거리 533 (명자김서면)', 'phone': '055-471-1319'}
# {'id': 218, 'name': '김은영', 'email': 'gimujin@example.com', 'address': '제주특별자치도 강릉시 양재천거리 107', 'phone': '061-081-8993'}
# {'id': 219, 'name': '양도윤', 'email': 'wgang@example.com', 'address': '충청북도 성남시 분당구 석촌호수거리 704-65 (순옥김이동)', 'phone': '052-067-6264'}
# {'id': 220, 'name': '서서준', 'email': 'hongsugja@example.com', 'address': '세종특별자치시 용산구 백제고분7길 540 (혜진이김동)', 'phone': '062-396-2454'}
# {'id': 221, 'name': '김중수', 'email': 'jeonghyi74@example.org', 'address': '경상북도 오산시 석촌호수844길 523-52 (현숙김김리)', 'phone': '041-942-4934'}
# {'id': 222, 'name': '김우진', 'email': 'gangseongsu@example.com', 'address': '전라북도 김포시 서초중앙83길 437', 'phone': '010-9209-5433'}
# {'id': 223, 'name': '박정숙', 'email': 'minjii@example.org', 'address': '충청남도 여주시 봉은사거리 771', 'phone': '053-852-3002'}
# {'id': 224, 'name': '김승민', 'email': 'jihun44@example.com', 'address': '대전광역시 동구 언주384로 832 (지민윤동)', 'phone': '053-755-0282'}
# {'id': 225, 'name': '배순옥', 'email': 'han@example.com', 'address': '강원도 보은군 강남대6길 485-36', 'phone': '041-188-6614'}
# {'id': 226, 'name': '김지영', 'email': 'hwangminseo@example.org', 'address': '전라남도 부천시 원미구 학동3로 7 (미영이동)', 'phone': '044-186-4441'}
# {'id': 227, 'name': '김경자', 'email': 'gyeongsu77@example.com', 'address': '강원도 태안군 서초중앙거리 300 (정희오마을)', 'phone': '070-7970-7524'}
# {'id': 228, 'name': '김중수', 'email': 'jiugim@example.org', 'address': '부산광역시 동작구 학동893가 968 (준혁강읍)', 'phone': '018-195-3912'}
# {'id': 229, 'name': '고경수', 'email': 'jaehyeonyun@example.com', 'address': '대구광역시 중랑구 선릉가 819', 'phone': '042-226-9189'}
# {'id': 230, 'name': '김영호', 'email': 'sjeong@example.org', 'address': '부산광역시 양천구 선릉231로 326-8', 'phone': '061-028-4925'}
# {'id': 231, 'name': '김영호', 'email': 'baegdohyeon@example.net', 'address': '부산광역시 강남구 논현83가 147 (순옥서김리)', 'phone': '032-560-0563'}
# {'id': 232, 'name': '박미경', 'email': 'jangseungmin@example.com', 'address': '부산광역시 종로구 석촌호수거리 666', 'phone': '018-223-5163'}
# {'id': 233, 'name': '나상철', 'email': 'byun@example.com', 'address': '제주특별자치도 보은군 삼성235거리 186 (하은오하마을)', 'phone': '063-120-3998'}
# {'id': 234, 'name': '박도현', 'email': 'agim@example.org', 'address': '대구광역시 성동구 오금길 674 (민수강나면)', 'phone': '044-870-4967'}
# {'id': 235, 'name': '정민재', 'email': 'ri@example.org', 'address': '경상북도 포천시 역삼40길 689-58', 'phone': '044-458-4311'}
# {'id': 236, 'name': '권서윤', 'email': 'gimyeongho@example.com', 'address': '대전광역시 서구 서초대가 398 (재현이리)', 'phone': '055-666-0519'}
# {'id': 237, 'name': '이재호', 'email': 'eunseo87@example.com', 'address': '인천광역시 동작구 압구정672가 928-51', 'phone': '031-999-7306'}
# {'id': 238, 'name': '이서준', 'email': 'seoyunhwang@example.org', 'address': '전라북도 부천시 원미구 영동대09거리 143-95', 'phone': '031-661-1988'}
# {'id': 239, 'name': '김정숙', 'email': 'iyeweon@example.com', 'address': '경상북도 고양시 일산서구 언주로 지하473 (혜진이마을)', 'phone': '032-707-0411'}
# {'id': 240, 'name': '김영철', 'email': 'geonu38@example.org', 'address': '광주광역시 용산구 가락거리 810 (광수서이면)', 'phone': '061-982-2547'}
# {'id': 241, 'name': '김순자', 'email': 'yeongja38@example.net', 'address': '울산광역시 동구 역삼94가 646', 'phone': '010-6040-0192'}
# {'id': 242, 'name': '오지연', 'email': 'jeongsungim@example.org', 'address': '서울특별시 구로구 양재천27거리 621-57', 'phone': '016-621-8464'}
# {'id': 243, 'name': '김영식', 'email': 'songyeonghwan@example.com', 'address': '울산광역시 강서구 서초대57로 지하235', 'phone': '043-861-9981'}
# {'id': 244, 'name': '이정훈', 'email': 'hongyejin@example.net', 'address': '전라남도 의정부시 테헤란거리 116-54', 'phone': '031-987-5731'}
# {'id': 245, 'name': '오병철', 'email': 'gyeonghyii@example.net', 'address': '충청남도 제천시 삼성5로 359 (명자성권면)', 'phone': '043-749-6522'}
# {'id': 246, 'name': '노현정', 'email': 'sanghogim@example.net', 'address': '세종특별자치시 은평구 영동대로 739-18', 'phone': '011-423-2370'}
# {'id': 247, 'name': '류예준', 'email': 'gimsugja@example.org', 'address': '인천광역시 강동구 잠실8거리 30 (서현고강리)', 'phone': '053-022-1179'}
# {'id': 248, 'name': '김서현', 'email': 'yeongsu97@example.org', 'address': '광주광역시 서대문구 도산대거리 지하439 (옥순김김동)', 'phone': '070-4236-4882'}
# {'id': 249, 'name': '김준호', 'email': 'mijeongnam@example.com', 'address': '충청남도 철원군 오금길 지하116 (광수김면)', 'phone': '042-865-0528'}
# {'id': 250, 'name': '조상훈', 'email': 'joyejun@example.net', 'address': '서울특별시 마포구 테헤란거리 2-84 (수민고면)', 'phone': '017-419-8386'}
# {'id': 251, 'name': '이보람', 'email': 'ggim@example.org', 'address': '전라북도 옥천군 서초대거리 823 (미정김동)', 'phone': '033-085-3969'}
# {'id': 252, 'name': '우경자', 'email': 'ssim@example.org', 'address': '경기도 예산군 서초대9가 581', 'phone': '016-885-4749'}
# {'id': 253, 'name': '홍승현', 'email': 'gyeongja08@example.net', 'address': '전라북도 안산시 단원구 반포대1거리 652-26 (시우이마을)', 'phone': '051-795-6821'}
# {'id': 254, 'name': '류서영', 'email': 'seonghyeongim@example.net', 'address': '경기도 홍천군 서초대로 966-60 (미숙한윤동)', 'phone': '061-529-6651'}
# {'id': 255, 'name': '김선영', 'email': 'hahyeonji@example.net', 'address': '경상남도 보령시 백제고분로 965-95', 'phone': '062-628-6013'}
# {'id': 256, 'name': '김정훈', 'email': 'baeyeongil@example.org', 'address': '세종특별자치시 서초구 압구정길 152 (보람송이마을)', 'phone': '032-186-0244'}
# {'id': 257, 'name': '박하은', 'email': 'bagyeweon@example.org', 'address': '서울특별시 남구 논현거리 969', 'phone': '019-220-5236'}
# {'id': 258, 'name': '송서영', 'email': 'junyeong21@example.org', 'address': '강원도 수원시 권선구 강남대길 943-49', 'phone': '02-0630-7198'}
# {'id': 259, 'name': '김성현', 'email': 'sunjagweon@example.org', 'address': '대전광역시 동대문구 압구정가 170-95 (준영박허마을)', 'phone': '031-045-0965'}
# {'id': 260, 'name': '노경수', 'email': 'pi@example.com', 'address': '서울특별시 영등포구 논현609로 지하418', 'phone': '042-935-1895'}
# {'id': 261, 'name': '나민석', 'email': 'eunjibag@example.org', 'address': '인천광역시 동작구 반포대가 789', 'phone': '054-665-1380'}
# {'id': 262, 'name': '박주원', 'email': 'pbaeg@example.org', 'address': '대구광역시 은평구 반포대95길 850', 'phone': '02-0952-2155'}
# {'id': 263, 'name': '이예준', 'email': 'seoyeonggim@example.com', 'address': '인천광역시 동구 테헤란로 657 (현우최허리)', 'phone': '053-627-8900'}
# {'id': 264, 'name': '김미정', 'email': 'imjunyeong@example.com', 'address': '충청남도 천안시 서북구 백제고분163길 536', 'phone': '042-549-8176'}
# {'id': 265, 'name': '임미영', 'email': 'seonghyeon31@example.net', 'address': '서울특별시 서초구 삼성거리 319-2 (진호김리)', 'phone': '051-313-5949'}
# {'id': 266, 'name': '이승민', 'email': 'ti@example.com', 'address': '경상남도 동두천시 오금거리 지하902', 'phone': '031-481-4230'}
# {'id': 267, 'name': '김광수', 'email': 'seongyejun@example.org', 'address': '경기도 화성시 테헤란길 349-30 (영진민동)', 'phone': '033-119-4840'}
# {'id': 268, 'name': '최은정', 'email': 'coedonghyeon@example.org', 'address': '울산광역시 광진구 반포대로 784 (현준이최마을)', 'phone': '070-7697-3216'}
# {'id': 269, 'name': '이준호', 'email': 'eunjeonggim@example.org', 'address': '전라북도 청주시 서원구 도산대3로 228', 'phone': '017-172-0666'}
# {'id': 270, 'name': '이서준', 'email': 'jiui@example.com', 'address': '울산광역시 송파구 오금1로 66', 'phone': '044-809-1488'}
# {'id': 271, 'name': '김수진', 'email': 'hyeonjun88@example.net', 'address': '경상남도 공주시 역삼5길 656-75', 'phone': '016-253-7486'}
# {'id': 272, 'name': '서예지', 'email': 'yeeunhan@example.net', 'address': '광주광역시 도봉구 반포대길 987-38', 'phone': '031-102-2612'}
# {'id': 273, 'name': '이은경', 'email': 'ki@example.org', 'address': '충청북도 용인시 수지구 언주로 979-13', 'phone': '032-108-7947'}
# {'id': 274, 'name': '김진우', 'email': 'isubin@example.net', 'address': '강원도 정선군 영동대43길 434 (현준진마을)', 'phone': '02-5040-0692'}
# {'id': 275, 'name': '이상현', 'email': 'seoyeongsin@example.net', 'address': '제주특별자치도 가평군 백제고분로 588-10 (수진김이리)', 'phone': '032-009-5244'}
# {'id': 276, 'name': '정성현', 'email': 'yunseoju@example.net', 'address': '충청북도 천안시 서북구 양재천가 178', 'phone': '010-1397-6012'}
# {'id': 277, 'name': '백경자', 'email': 'yeongsig94@example.org', 'address': '경상북도 양평군 봉은사거리 지하507', 'phone': '064-763-9852'}
# {'id': 278, 'name': '김정순', 'email': 'yeongsu02@example.org', 'address': '서울특별시 성북구 개포61가 533 (현정이읍)', 'phone': '051-459-9837'}
# {'id': 279, 'name': '문지원', 'email': 'mson@example.net', 'address': '서울특별시 노원구 선릉길 423 (준호배이동)', 'phone': '043-070-4096'}
# {'id': 280, 'name': '박상호', 'email': 'jeongsuggim@example.org', 'address': '대구광역시 영등포구 도산대842로 567', 'phone': '019-371-9414'}
# {'id': 281, 'name': '박예은', 'email': 'gimjinu@example.net', 'address': '경상남도 안양시 만안구 논현길 725', 'phone': '053-897-3220'}
# {'id': 282, 'name': '민정호', 'email': 'hanhyejin@example.com', 'address': '세종특별자치시 강동구 가락95거리 지하422 (정식이김읍)', 'phone': '070-1271-7761'}
# {'id': 283, 'name': '이아름', 'email': 'gyeongsugim@example.net', 'address': '경상북도 여주시 반포대817가 36', 'phone': '018-733-9195'}
# {'id': 284, 'name': '박윤서', 'email': 'yunjeongsug@example.net', 'address': '충청북도 옥천군 테헤란로 491-20', 'phone': '033-746-6469'}
# {'id': 285, 'name': '이지은', 'email': 'ogjagang@example.net', 'address': '경상북도 춘천시 개포길 312-14', 'phone': '031-168-1614'}
# {'id': 286, 'name': '이서연', 'email': 'gyeongsu12@example.net', 'address': '세종특별자치시 서구 가락766로 지하891 (서영이노동)', 'phone': '018-492-5897'}
# {'id': 287, 'name': '최혜진', 'email': 'sangho72@example.com', 'address': '경상남도 김포시 서초대거리 920 (미영최노마을)', 'phone': '063-586-4265'}
# {'id': 288, 'name': '이광수', 'email': 'ghwang@example.com', 'address': '충청남도 진천군 서초대로 238-22 (현지이리)', 'phone': '018-773-5304'}
# {'id': 289, 'name': '최성수', 'email': 'junseobag@example.net', 'address': '대구광역시 노원구 선릉2가 645 (현우김마을)', 'phone': '055-676-6018'}
# {'id': 290, 'name': '허순옥', 'email': 'hgim@example.org', 'address': '전라남도 광주시 테헤란0길 지하788', 'phone': '018-146-7077'}
# {'id': 291, 'name': '이영식', 'email': 'gimseonyeong@example.com', 'address': '울산광역시 마포구 반포대828거리 지하209 (경희이김읍)', 'phone': '017-625-5018'}
# {'id': 292, 'name': '서현준', 'email': 'jeongsug49@example.com', 'address': '부산광역시 동작구 압구정길 386', 'phone': '033-010-4836'}
# {'id': 293, 'name': '김경희', 'email': 'hongjiu@example.com', 'address': '인천광역시 종로구 반포대667가 240-97 (수빈송최동)', 'phone': '052-248-2292'}
# {'id': 294, 'name': '김하은', 'email': 'ujingim@example.org', 'address': '세종특별자치시 중구 테헤란151가 405 (서연권동)', 'phone': '031-131-4323'}
# {'id': 295, 'name': '김상철', 'email': 'gimhyeonsug@example.org', 'address': '광주광역시 성북구 삼성00가 430 (민서문면)', 'phone': '016-685-1021'}
# {'id': 296, 'name': '하민재', 'email': 'jeongnam03@example.net', 'address': '전라남도 수원시 언주거리 804-40', 'phone': '051-909-4540'}
# {'id': 297, 'name': '윤재호', 'email': 'gimyeongmi@example.com', 'address': '세종특별자치시 중랑구 역삼1가 지하43 (지아한마을)', 'phone': '052-258-1655'}
# {'id': 298, 'name': '박재호', 'email': 'iseonghun@example.com', 'address': '부산광역시 강남구 영동대가 400-2 (은영이리)', 'phone': '062-845-7707'}
# {'id': 299, 'name': '강서현', 'email': 'gweonujin@example.com', 'address': '전라북도 계룡시 반포대220가 543-72', 'phone': '051-115-6356'}
# {'id': 300, 'name': '류지민', 'email': 'seunghyeon50@example.net', 'address': '전라북도 평택시 가락로 7-92 (보람손면)', 'phone': '044-546-2904'}
# {'id': 301, 'name': '김영호', 'email': 'seongminsong@example.net', 'address': '광주광역시 남구 가락8로 217-34 (옥순이읍)', 'phone': '053-727-2377'}
# {'id': 302, 'name': '안수빈', 'email': 'seongho24@example.com', 'address': '광주광역시 종로구 반포대로 788-55', 'phone': '019-835-0413'}
# {'id': 303, 'name': '박순옥', 'email': 'jeongsig20@example.net', 'address': '충청남도 고양시 덕양구 영동대거리 978', 'phone': '016-702-7754'}
# {'id': 304, 'name': '박정식', 'email': 'miyeong85@example.com', 'address': '광주광역시 용산구 역삼거리 702-70', 'phone': '011-350-3336'}
# {'id': 305, 'name': '임경숙', 'email': 'hyeonjun62@example.com', 'address': '경기도 서천군 선릉가 685 (성훈신동)', 'phone': '064-718-9805'}
# {'id': 306, 'name': '박성수', 'email': 'isumin@example.org', 'address': '인천광역시 노원구 테헤란543가 지하659 (현준송윤마을)', 'phone': '016-142-3676'}
# {'id': 307, 'name': '김지후', 'email': 'gimjeongsu@example.org', 'address': '강원도 성남시 중원구 오금거리 923 (정희김안읍)', 'phone': '016-953-2988'}
# {'id': 308, 'name': '김진우', 'email': 'hyeonsug34@example.org', 'address': '광주광역시 강남구 삼성642거리 지하101', 'phone': '052-535-5587'}
# {'id': 309, 'name': '김예지', 'email': 'doyungim@example.net', 'address': '경상남도 원주시 양재천0가 772 (병철이면)', 'phone': '017-504-9984'}
# {'id': 310, 'name': '김승민', 'email': 'yeongsui@example.com', 'address': '울산광역시 용산구 역삼42가 915', 'phone': '051-047-5631'}
# {'id': 311, 'name': '김지훈', 'email': 'jaehyeonjeong@example.org', 'address': '충청남도 청주시 상당구 삼성거리 426', 'phone': '031-055-4434'}
# {'id': 312, 'name': '박수빈', 'email': 'yeweon16@example.com', 'address': '전라북도 논산시 봉은사가 112', 'phone': '044-188-6131'}
# {'id': 313, 'name': '권정훈', 'email': 'hwangjeonghun@example.net', 'address': '경상남도 수원시 장안구 학동거리 898', 'phone': '055-104-4425'}
# {'id': 314, 'name': '이은서', 'email': 'jeongsuggim@example.net', 'address': '세종특별자치시 서구 백제고분002거리 819-71 (수빈이박읍)', 'phone': '054-850-0152'}
# {'id': 315, 'name': '정은주', 'email': 'gimdonghyeon@example.org', 'address': '서울특별시 중랑구 도산대가 177-91', 'phone': '053-221-3088'}
# {'id': 316, 'name': '나상훈', 'email': 'yunsangho@example.com', 'address': '세종특별자치시 성북구 석촌호수가 210-27', 'phone': '070-0736-9913'}
# {'id': 317, 'name': '이정남', 'email': 'heominseo@example.net', 'address': '경상남도 광명시 논현가 454', 'phone': '053-628-7292'}
# {'id': 318, 'name': '김성호', 'email': 'eunjian@example.com', 'address': '서울특별시 동구 강남대로 47-8 (도현이김마을)', 'phone': '052-985-7729'}
# {'id': 319, 'name': '이옥순', 'email': 'baegjeongsun@example.net', 'address': '전라북도 철원군 도산대가 50-19', 'phone': '011-865-5603'}
# {'id': 320, 'name': '김영식', 'email': 'minjun74@example.com', 'address': '울산광역시 종로구 테헤란로 623-80 (성호이읍)', 'phone': '051-420-2454'}
# {'id': 321, 'name': '최명숙', 'email': 'xgim@example.org', 'address': '울산광역시 성북구 학동93거리 528-5 (경숙김이마을)', 'phone': '042-866-6186'}
# {'id': 322, 'name': '박유진', 'email': 'gi@example.net', 'address': '광주광역시 동구 선릉279거리 8-83 (현우한읍)', 'phone': '063-184-3467'}
# {'id': 323, 'name': '김병철', 'email': 'sanghun33@example.net', 'address': '충청남도 광주시 압구정9거리 459', 'phone': '042-845-3365'}
# {'id': 324, 'name': '김상호', 'email': 'di@example.net', 'address': '강원도 성남시 언주981거리 959-2', 'phone': '042-992-0460'}
# {'id': 325, 'name': '김아름', 'email': 'yi@example.org', 'address': '세종특별자치시 금천구 개포3거리 지하593', 'phone': '061-287-5055'}
# {'id': 326, 'name': '서상훈', 'email': 'seojun11@example.com', 'address': '전라북도 안산시 테헤란876거리 426-11', 'phone': '033-992-9251'}
# {'id': 327, 'name': '이영순', 'email': 'seonyeong81@example.org', 'address': '세종특별자치시 강서구 강남대로 602 (은서강동)', 'phone': '053-371-0994'}
# {'id': 328, 'name': '김현지', 'email': 'bagdohyeon@example.com', 'address': '경기도 삼척시 반포대길 779-91', 'phone': '010-7593-9436'}
# {'id': 329, 'name': '김영호', 'email': 'jeonghuncoe@example.net', 'address': '경상북도 충주시 반포대450길 348', 'phone': '055-801-0854'}
# {'id': 330, 'name': '이재호', 'email': 'coeminjae@example.com', 'address': '경상북도 증평군 잠실24거리 764 (민재김마을)', 'phone': '010-6383-3592'}
# {'id': 331, 'name': '백은영', 'email': 'ujin35@example.net', 'address': '서울특별시 강동구 강남대322길 143 (지영심마을)', 'phone': '010-2953-5911'}
# {'id': 332, 'name': '박정수', 'email': 'geonugim@example.net', 'address': '전라북도 청주시 청원구 가락거리 932-96 (하은최서마을)', 'phone': '02-2337-5462'}
# {'id': 333, 'name': '김서연', 'email': 'hwangseoyeong@example.net', 'address': '부산광역시 북구 반포대가 지하798', 'phone': '064-737-5257'}
# {'id': 334, 'name': '이성진', 'email': 'rbag@example.org', 'address': '전라남도 부여군 도산대8거리 625-10 (영희윤면)', 'phone': '044-794-5283'}
# {'id': 335, 'name': '홍지연', 'email': 'gangjiyeon@example.net', 'address': '강원도 계룡시 봉은사6가 367 (지훈이읍)', 'phone': '051-774-6866'}
# {'id': 336, 'name': '김지후', 'email': 'fjang@example.com', 'address': '대전광역시 동대문구 강남대49가 지하582', 'phone': '02-0663-1285'}
# {'id': 337, 'name': '이민재', 'email': 'ubag@example.com', 'address': '제주특별자치도 수원시 장안구 논현0길 354 (성수김안면)', 'phone': '011-468-6508'}
# {'id': 338, 'name': '안지훈', 'email': 'ii@example.com', 'address': '인천광역시 중랑구 선릉거리 239 (성현박면)', 'phone': '064-791-1091'}
# {'id': 339, 'name': '이현준', 'email': 'ryujeongnam@example.org', 'address': '제주특별자치도 성남시 수정구 봉은사31길 288-17 (은영최김리)', 'phone': '016-015-7889'}
# {'id': 340, 'name': '박진우', 'email': 'ygim@example.org', 'address': '강원도 수원시 권선구 석촌호수030로 지하771', 'phone': '051-031-5090'}
# {'id': 341, 'name': '이상철', 'email': 'minjae15@example.org', 'address': '경기도 춘천시 도산대61로 520-63', 'phone': '070-2675-7801'}
# {'id': 342, 'name': '이미경', 'email': 'kgim@example.org', 'address': '대구광역시 관악구 석촌호수가 366', 'phone': '041-938-8110'}
# {'id': 343, 'name': '박유진', 'email': 'isanghyeon@example.net', 'address': '경상남도 동해시 잠실로 645 (도현조동)', 'phone': '051-211-2495'}
# {'id': 344, 'name': '주하윤', 'email': 'ebag@example.net', 'address': '전라북도 영동군 논현로 696 (혜진곽박리)', 'phone': '02-9319-2752'}
# {'id': 345, 'name': '김준영', 'email': 'bi@example.com', 'address': '전라남도 수원시 권선구 언주길 270 (지은김전읍)', 'phone': '018-402-6752'}
# {'id': 346, 'name': '구주원', 'email': 'ano@example.net', 'address': '전라남도 양구군 양재천2거리 561 (성훈최문읍)', 'phone': '018-604-5827'}
# {'id': 347, 'name': '박정희', 'email': 'jeongsugmun@example.com', 'address': '부산광역시 서초구 봉은사51로 246-30', 'phone': '051-914-9169'}
# {'id': 348, 'name': '최병철', 'email': 'gimjihye@example.com', 'address': '인천광역시 동작구 삼성99가 123-28', 'phone': '019-234-7376'}
# {'id': 349, 'name': '김선영', 'email': 'yeongho63@example.com', 'address': '부산광역시 송파구 봉은사거리 543', 'phone': '063-579-5176'}
# {'id': 350, 'name': '장보람', 'email': 'cunja86@example.com', 'address': '경상북도 청양군 논현4거리 496-66', 'phone': '011-044-0959'}
# {'id': 351, 'name': '김수민', 'email': 'jieunseo@example.com', 'address': '경상북도 수원시 권선구 서초대로 285-70 (승민김안동)', 'phone': '062-255-3598'}
# {'id': 352, 'name': '김준영', 'email': 'sangceolcoe@example.org', 'address': '충청남도 예산군 백제고분거리 685-23 (민재최양동)', 'phone': '044-709-5873'}
# {'id': 353, 'name': '고유진', 'email': 'gimjaeho@example.org', 'address': '광주광역시 종로구 삼성가 27-4', 'phone': '033-103-3717'}
# {'id': 354, 'name': '차정수', 'email': 'jeongsunbag@example.com', 'address': '대구광역시 관악구 가락7로 181-47', 'phone': '044-490-6463'}
# {'id': 355, 'name': '서도윤', 'email': 'sangho43@example.com', 'address': '울산광역시 동작구 가락59가 654 (지후최면)', 'phone': '011-872-3562'}
# {'id': 356, 'name': '지중수', 'email': 'iyujin@example.com', 'address': '경상북도 동해시 가락113로 613', 'phone': '070-0745-3104'}
# {'id': 357, 'name': '윤지우', 'email': 'yeonghogim@example.org', 'address': '전라북도 수원시 도산대가 지하946 (정순서리)', 'phone': '062-910-8060'}
# {'id': 358, 'name': '김중수', 'email': 'coehyeonu@example.com', 'address': '충청북도 영동군 학동거리 697-29 (정희서이동)', 'phone': '061-772-8539'}
# {'id': 359, 'name': '권은정', 'email': 'jia58@example.com', 'address': '전라남도 태백시 삼성573길 917', 'phone': '054-004-7310'}
# {'id': 360, 'name': '주진우', 'email': 'qgim@example.net', 'address': '충청남도 화성시 백제고분336가 992 (영미박리)', 'phone': '055-313-3477'}
# {'id': 361, 'name': '윤동현', 'email': 'ijieun@example.net', 'address': '울산광역시 용산구 오금0거리 634 (영식강면)', 'phone': '011-629-1812'}
# {'id': 362, 'name': '김종수', 'email': 'gimjia@example.org', 'address': '대전광역시 관악구 잠실가 550', 'phone': '02-8959-4497'}
# {'id': 363, 'name': '김예진', 'email': 'rbaeg@example.com', 'address': '경상남도 원주시 삼성43거리 75', 'phone': '010-0385-9071'}
# {'id': 364, 'name': '김종수', 'email': 'hwangyeonghwan@example.com', 'address': '전라남도 용인시 수지구 학동29로 219 (예진오리)', 'phone': '061-237-7406'}
# {'id': 365, 'name': '김채원', 'email': 'anjiweon@example.com', 'address': '경상북도 고양시 덕양구 영동대8길 582', 'phone': '017-303-4605'}
# {'id': 366, 'name': '차성현', 'email': 'minjaei@example.org', 'address': '경기도 안양시 만안구 오금로 915-63', 'phone': '032-038-2843'}
# {'id': 367, 'name': '이영환', 'email': 'eunjeongbag@example.org', 'address': '인천광역시 광진구 영동대로 528', 'phone': '031-655-6771'}
# {'id': 368, 'name': '박서준', 'email': 'usong@example.com', 'address': '울산광역시 양천구 압구정가 지하200 (명숙홍읍)', 'phone': '051-907-6807'}
# {'id': 369, 'name': '박지아', 'email': 'yejuni@example.org', 'address': '전라북도 안양시 만안구 학동486로 423-11 (성민박면)', 'phone': '02-5511-2577'}
# {'id': 370, 'name': '문진우', 'email': 'mno@example.org', 'address': '서울특별시 동대문구 양재천가 872-39', 'phone': '032-165-2898'}
# {'id': 371, 'name': '이지후', 'email': 'jaehyeonbag@example.com', 'address': '충청북도 영동군 테헤란가 285 (아름박손리)', 'phone': '017-302-8381'}
# {'id': 372, 'name': '권준서', 'email': 'haeungim@example.org', 'address': '강원도 수원시 영통구 언주거리 584', 'phone': '031-852-8384'}
# {'id': 373, 'name': '이준서', 'email': 'vseo@example.org', 'address': '광주광역시 동구 영동대거리 365', 'phone': '032-966-0623'}
# {'id': 374, 'name': '김현정', 'email': 'seonghyeonyun@example.net', 'address': '대구광역시 용산구 강남대312거리 지하5', 'phone': '052-161-0844'}
# {'id': 375, 'name': '안옥자', 'email': 'doyun57@example.net', 'address': '광주광역시 북구 서초대가 775', 'phone': '032-475-2523'}
# {'id': 376, 'name': '권도윤', 'email': 'gimsunja@example.org', 'address': '충청북도 속초시 선릉90가 612 (은서구마을)', 'phone': '055-887-2366'}
# {'id': 377, 'name': '강선영', 'email': 'ogja38@example.com', 'address': '충청북도 청주시 흥덕구 개포613가 지하988', 'phone': '070-0282-4045'}
# {'id': 378, 'name': '홍지영', 'email': 'yejii@example.com', 'address': '충청남도 이천시 봉은사7길 399-5', 'phone': '063-053-4031'}
# {'id': 379, 'name': '김정남', 'email': 'ii@example.com', 'address': '부산광역시 성동구 언주가 지하44', 'phone': '017-185-9336'}
# {'id': 380, 'name': '김도윤', 'email': 'bagyeongceol@example.net', 'address': '경상남도 안양시 잠실98거리 680 (종수배홍마을)', 'phone': '052-405-1661'}
# {'id': 381, 'name': '권성진', 'email': 'ogwag@example.org', 'address': '제주특별자치도 삼척시 가락2거리 721', 'phone': '017-134-5645'}
# {'id': 382, 'name': '고민준', 'email': 'gyeongsu06@example.net', 'address': '울산광역시 동대문구 양재천로 231-64 (지연이동)', 'phone': '043-918-4479'}
# {'id': 383, 'name': '이영호', 'email': 'wgu@example.net', 'address': '경상남도 평택시 오금6길 710-21 (현지이김면)', 'phone': '017-732-4067'}
# {'id': 384, 'name': '윤병철', 'email': 'imhaeun@example.com', 'address': '전라북도 동두천시 양재천961길 지하729 (예진구리)', 'phone': '011-797-7886'}
# {'id': 385, 'name': '김성진', 'email': 'junyeongi@example.com', 'address': '강원도 남양주시 역삼로 673-16 (혜진김읍)', 'phone': '018-998-0475'}
# {'id': 386, 'name': '이정식', 'email': 'seojihu@example.net', 'address': '경기도 화천군 논현로 284', 'phone': '051-040-3991'}
# {'id': 387, 'name': '박민준', 'email': 'gimminsu@example.net', 'address': '대구광역시 구로구 도산대길 506', 'phone': '070-3982-9000'}
# ...
# {'id': 873, 'name': '지광수', 'email': 'seoyeongsong@example.net', 'address': '충청남도 양평군 도산대26길 327-74', 'phone': '044-455-0817'}
# {'id': 874, 'name': '박미숙', 'email': 'bgim@example.net', 'address': '대전광역시 노원구 도산대3길 726', 'phone': '010-0850-4727'}
# {'id': 875, 'name': '김지아', 'email': 'jeongsiggim@example.net', 'address': '부산광역시 동대문구 서초중앙거리 지하597', 'phone': '017-450-9491'}
# {'id': 876, 'name': '황하은', 'email': 'yeweon08@example.net', 'address': '경상북도 공주시 선릉00거리 137 (지아김이읍)', 'phone': '061-200-9479'}
# {'id': 877, 'name': '김경수', 'email': 'lgim@example.org', 'address': '경상북도 홍천군 영동대거리 196-29', 'phone': '061-820-7472'}
# {'id': 878, 'name': '김성수', 'email': 'jinu13@example.com', 'address': '충청남도 군포시 오금길 151 (진호송김읍)', 'phone': '031-058-2367'}
# {'id': 879, 'name': '박정웅', 'email': 'seungmin42@example.com', 'address': '충청남도 천안시 동남구 백제고분1거리 729-80 (종수이김읍)', 'phone': '062-021-5361'}
# {'id': 880, 'name': '전현주', 'email': 'acoe@example.org', 'address': '세종특별자치시 송파구 강남대143가 138-96 (민지박마을)', 'phone': '043-236-9252'}
# {'id': 881, 'name': '이하은', 'email': 'yeongsiggang@example.net', 'address': '제주특별자치도 양구군 서초대0로 337-36 (동현김배리)', 'phone': '070-5221-6941'}
# {'id': 882, 'name': '양영길', 'email': 'minseo20@example.net', 'address': '강원도 고양시 도산대9로 986 (서윤장마을)', 'phone': '054-836-9719'}
# {'id': 883, 'name': '이지원', 'email': 'subini@example.net', 'address': '광주광역시 동대문구 논현로 871', 'phone': '010-2313-0746'}
# {'id': 884, 'name': '심준영', 'email': 'areum59@example.net', 'address': '경기도 속초시 언주가 634 (지원김노읍)', 'phone': '042-784-8824'}
# {'id': 885, 'name': '이병철', 'email': 'sangceol56@example.net', 'address': '부산광역시 노원구 학동37로 412 (경자황읍)', 'phone': '011-923-9871'}
# {'id': 886, 'name': '박서영', 'email': 'jeongnam77@example.org', 'address': '울산광역시 송파구 서초중앙길 127 (은서이마을)', 'phone': '018-983-9625'}
# {'id': 887, 'name': '최지연', 'email': 'byeongceolnam@example.net', 'address': '충청북도 계룡시 서초중앙327길 지하283 (은지윤김면)', 'phone': '033-148-0989'}
# {'id': 888, 'name': '김예은', 'email': 'yeongsun62@example.net', 'address': '세종특별자치시 송파구 역삼로 지하30 (준서노전면)', 'phone': '016-676-8413'}
# {'id': 889, 'name': '김진우', 'email': 'doyun61@example.com', 'address': '충청북도 수원시 잠실6길 지하740', 'phone': '011-316-6324'}
# {'id': 890, 'name': '윤현우', 'email': 'areum03@example.org', 'address': '인천광역시 용산구 삼성거리 지하277 (예은허마을)', 'phone': '061-429-9222'}
# {'id': 891, 'name': '안성호', 'email': 'yejin51@example.net', 'address': '충청북도 원주시 석촌호수로 893', 'phone': '018-205-3748'}
# {'id': 892, 'name': '김하윤', 'email': 'yeonggilgang@example.net', 'address': '세종특별자치시 서초구 학동277가 지하152 (시우이심면)', 'phone': '018-365-3255'}
# {'id': 893, 'name': '박정남', 'email': 'seoseongsu@example.net', 'address': '경상남도 삼척시 서초대가 391-41 (예지김곽마을)', 'phone': '033-743-6015'}
# {'id': 894, 'name': '김지민', 'email': 'gimboram@example.com', 'address': '경상북도 안양시 만안구 도산대로 774 (은경최마을)', 'phone': '02-6805-9116'}
# {'id': 895, 'name': '노지아', 'email': 'myeongsuggim@example.org', 'address': '세종특별자치시 금천구 삼성거리 618 (영숙나심리)', 'phone': '010-2046-6838'}
# {'id': 896, 'name': '김건우', 'email': 'yeonghyiyun@example.org', 'address': '광주광역시 도봉구 삼성거리 446-37 (예준윤마을)', 'phone': '017-209-5240'}
# {'id': 897, 'name': '이민서', 'email': 'jangcaeweon@example.org', 'address': '강원도 서산시 서초중앙로 93', 'phone': '044-000-9413'}
# {'id': 898, 'name': '이종수', 'email': 'munyeonghyi@example.com', 'address': '충청북도 아산시 서초대거리 831 (재호황송읍)', 'phone': '011-193-0134'}
# {'id': 899, 'name': '김정식', 'email': 'haminji@example.net', 'address': '부산광역시 용산구 강남대거리 118-94 (영미문손마을)', 'phone': '031-431-4604'}
# {'id': 900, 'name': '김성훈', 'email': 'gimyujin@example.net', 'address': '인천광역시 남구 봉은사길 870 (지영황면)', 'phone': '064-705-6010'}
# {'id': 901, 'name': '김예지', 'email': 'cjang@example.net', 'address': '대구광역시 노원구 압구정1가 519 (미숙박이면)', 'phone': '053-896-9700'}
# {'id': 902, 'name': '백준호', 'email': 'dyun@example.org', 'address': '제주특별자치도 삼척시 강남대02거리 405 (종수서황리)', 'phone': '011-627-5298'}
# {'id': 903, 'name': '황아름', 'email': 'ijaeho@example.net', 'address': '울산광역시 동구 백제고분가 906 (영철주면)', 'phone': '02-0155-0186'}
# {'id': 904, 'name': '손성민', 'email': 'ugweon@example.net', 'address': '광주광역시 강북구 서초중앙879로 626-59', 'phone': '031-550-9846'}
# {'id': 905, 'name': '김지영', 'email': 'hseo@example.net', 'address': '전라북도 괴산군 서초대98거리 지하55 (정숙박리)', 'phone': '054-832-2127'}
# {'id': 906, 'name': '안정훈', 'email': 'bagogja@example.org', 'address': '세종특별자치시 강동구 반포대길 545-38', 'phone': '033-432-2525'}
# {'id': 907, 'name': '이은정', 'email': 'jeongsigmun@example.net', 'address': '인천광역시 용산구 백제고분67거리 993', 'phone': '019-950-9400'}
# {'id': 908, 'name': '이정희', 'email': 'pi@example.org', 'address': '충청북도 양평군 잠실6가 125-78 (진우이이마을)', 'phone': '063-079-9330'}
# {'id': 909, 'name': '이진우', 'email': 'jieun07@example.org', 'address': '강원도 고양시 일산서구 서초대752가 863', 'phone': '02-8431-4992'}
# {'id': 910, 'name': '김선영', 'email': 'dhwang@example.net', 'address': '울산광역시 강서구 도산대60가 999-27', 'phone': '053-119-4494'}
# {'id': 911, 'name': '강정희', 'email': 'ieunseo@example.org', 'address': '경기도 태안군 백제고분로 855-23 (영길한이동)', 'phone': '041-350-2442'}
# {'id': 912, 'name': '김정식', 'email': 'xgim@example.net', 'address': '충청남도 연천군 도산대로 406 (예준김마을)', 'phone': '032-074-6456'}
# {'id': 913, 'name': '최영길', 'email': 'iyeonghyi@example.net', 'address': '대구광역시 북구 봉은사5로 508 (민준김면)', 'phone': '019-866-2163'}
# {'id': 914, 'name': '한주원', 'email': 'gimjeonghun@example.net', 'address': '제주특별자치도 포천시 논현303길 542 (미정김리)', 'phone': '053-609-3004'}
# {'id': 915, 'name': '김도윤', 'email': 'ryugyeonghyi@example.com', 'address': '세종특별자치시 강동구 오금45가 636-75 (영일박마을)', 'phone': '033-297-8370'}
# {'id': 916, 'name': '차병철', 'email': 'psong@example.com', 'address': '부산광역시 구로구 석촌호수가 869', 'phone': '017-716-0081'}
# {'id': 917, 'name': '이동현', 'email': 'migyeong36@example.org', 'address': '전라남도 부천시 원미구 오금43로 478 (지우김읍)', 'phone': '051-014-0572'}
# {'id': 918, 'name': '박현숙', 'email': 'agang@example.org', 'address': '세종특별자치시 서구 학동3로 지하194', 'phone': '032-891-9100'}
# {'id': 919, 'name': '문채원', 'email': 'yunseo09@example.net', 'address': '부산광역시 강남구 선릉54거리 지하376', 'phone': '018-682-9291'}
# {'id': 920, 'name': '강은경', 'email': 'hyeonsug67@example.com', 'address': '울산광역시 양천구 석촌호수가 505-30', 'phone': '02-8968-1511'}
# {'id': 921, 'name': '강도현', 'email': 'jaeho72@example.org', 'address': '충청북도 안성시 오금로 699-62 (민재김박면)', 'phone': '018-597-1551'}
# {'id': 922, 'name': '송준서', 'email': 'ogsunbag@example.net', 'address': '대전광역시 광진구 삼성거리 113-26 (영희이김리)', 'phone': '063-438-5708'}
# {'id': 923, 'name': '지현준', 'email': 'eomsugja@example.net', 'address': '대전광역시 동작구 언주24로 776-32 (정수문권읍)', 'phone': '010-9427-5775'}
# {'id': 924, 'name': '오옥순', 'email': 'junyeong64@example.net', 'address': '울산광역시 동대문구 강남대606거리 792 (경수박이면)', 'phone': '063-177-1305'}
# {'id': 925, 'name': '박은영', 'email': 'yeeungim@example.org', 'address': '충청남도 의왕시 강남대가 430-87', 'phone': '061-551-3899'}
# {'id': 926, 'name': '이도윤', 'email': 'igim@example.net', 'address': '경상남도 시흥시 석촌호수거리 419 (은주문오마을)', 'phone': '070-5343-5011'}
# {'id': 927, 'name': '김현지', 'email': 'simsunja@example.net', 'address': '대구광역시 동대문구 석촌호수길 799 (은지김김면)', 'phone': '063-795-0135'}
# {'id': 928, 'name': '한미정', 'email': 'yejingim@example.net', 'address': '세종특별자치시 성동구 언주로 지하42 (지현김면)', 'phone': '016-639-2351'}
# {'id': 929, 'name': '류성진', 'email': 'ujinyun@example.org', 'address': '광주광역시 종로구 백제고분가 597', 'phone': '010-8419-1788'}
# {'id': 930, 'name': '송성훈', 'email': 'sumin91@example.net', 'address': '인천광역시 양천구 삼성912거리 283 (정수이권동)', 'phone': '02-9119-3590'}
# {'id': 931, 'name': '이정희', 'email': 'tgim@example.com', 'address': '인천광역시 도봉구 백제고분45길 873 (영희김마을)', 'phone': '02-3674-6221'}
# {'id': 932, 'name': '최서현', 'email': 'ujinseo@example.com', 'address': '대전광역시 성동구 백제고분8길 지하653', 'phone': '052-369-4337'}
# {'id': 933, 'name': '김옥순', 'email': 'gyeongjacoe@example.net', 'address': '강원도 천안시 동남구 서초대로 지하795', 'phone': '052-740-8489'}
# {'id': 934, 'name': '하영숙', 'email': 'myang@example.com', 'address': '경상북도 군포시 논현길 596 (미숙허면)', 'phone': '011-874-5930'}
# {'id': 935, 'name': '박준혁', 'email': 'minjun79@example.net', 'address': '강원도 평창군 언주13거리 545', 'phone': '031-264-4214'}
# {'id': 936, 'name': '황영진', 'email': 'hyejingim@example.org', 'address': '광주광역시 서구 도산대48거리 407', 'phone': '033-916-4466'}
# {'id': 937, 'name': '김지연', 'email': 'ogja75@example.com', 'address': '광주광역시 양천구 잠실로 지하203', 'phone': '02-5249-5545'}
# {'id': 938, 'name': '배주원', 'email': 'cgim@example.net', 'address': '대구광역시 강북구 오금125가 166 (채원윤마을)', 'phone': '010-7082-7624'}
# {'id': 939, 'name': '지지훈', 'email': 'jeonghun22@example.net', 'address': '경상남도 홍천군 논현763로 866', 'phone': '063-801-4257'}
# {'id': 940, 'name': '김예준', 'email': 'gimminseog@example.org', 'address': '충청남도 포천시 역삼0로 304 (지혜이마을)', 'phone': '018-322-2062'}
# {'id': 941, 'name': '김영수', 'email': 'wbaeg@example.org', 'address': '전라남도 광주시 잠실95거리 937 (경숙허김마을)', 'phone': '017-810-3227'}
# {'id': 942, 'name': '윤중수', 'email': 'ujang@example.net', 'address': '제주특별자치도 청주시 청원구 서초중앙806거리 836 (지민한박읍)', 'phone': '044-243-1042'}
# {'id': 943, 'name': '김중수', 'email': 'eunseogim@example.com', 'address': '제주특별자치도 화성시 압구정로 506 (민준류이마을)', 'phone': '02-8585-9279'}
# {'id': 944, 'name': '임미경', 'email': 'minjaei@example.net', 'address': '제주특별자치도 여주시 역삼로 588', 'phone': '044-477-6133'}
# {'id': 945, 'name': '김현지', 'email': 'eunseogim@example.org', 'address': '충청남도 단양군 언주가 284-80 (성훈이김읍)', 'phone': '053-903-2773'}
# {'id': 946, 'name': '하서영', 'email': 'heogyeongsug@example.org', 'address': '인천광역시 금천구 오금로 지하628 (채원김리)', 'phone': '016-876-8103'}
# {'id': 947, 'name': '최상호', 'email': 'gimeunseo@example.org', 'address': '인천광역시 성북구 개포로 116', 'phone': '018-969-7054'}
# {'id': 948, 'name': '최경자', 'email': 'bagcunja@example.org', 'address': '경기도 부천시 오정구 반포대742로 824 (재호김면)', 'phone': '016-550-4289'}
# {'id': 949, 'name': '이준서', 'email': 'fgim@example.com', 'address': '경상북도 예산군 역삼147길 지하79', 'phone': '052-456-7006'}
# {'id': 950, 'name': '송영철', 'email': 'hayun80@example.org', 'address': '대전광역시 남구 봉은사길 640 (영수김동)', 'phone': '070-3699-9802'}
# {'id': 951, 'name': '박우진', 'email': 'joeunji@example.net', 'address': '부산광역시 용산구 영동대9로 28-58', 'phone': '052-613-7682'}
# {'id': 952, 'name': '김주원', 'email': 'yi@example.net', 'address': '강원도 부천시 소사구 백제고분가 337-16', 'phone': '011-766-2995'}
# {'id': 953, 'name': '안예원', 'email': 'jihyeca@example.org', 'address': '서울특별시 송파구 반포대97로 731-97 (준호안김동)', 'phone': '018-911-6870'}
# {'id': 954, 'name': '박순자', 'email': 'hgo@example.org', 'address': '제주특별자치도 안산시 상록구 서초중앙21거리 708-70', 'phone': '043-274-9674'}
# {'id': 955, 'name': '박종수', 'email': 'seonghun70@example.net', 'address': '울산광역시 도봉구 석촌호수681길 253-97', 'phone': '042-595-0790'}
# {'id': 956, 'name': '박진호', 'email': 'jaehobag@example.net', 'address': '인천광역시 은평구 테헤란362길 지하359 (정숙박마을)', 'phone': '054-512-1127'}
# {'id': 957, 'name': '김진호', 'email': 'fgim@example.org', 'address': '대구광역시 북구 강남대거리 722', 'phone': '053-043-2228'}
# {'id': 958, 'name': '황영자', 'email': 'jeonghyigu@example.net', 'address': '경기도 고양시 일산동구 잠실로 766 (수빈홍김마을)', 'phone': '017-526-5551'}
# {'id': 959, 'name': '고선영', 'email': 'imijeong@example.com', 'address': '인천광역시 서대문구 강남대거리 284-83', 'phone': '043-068-7533'}
# {'id': 960, 'name': '이지원', 'email': 'seonyeongjang@example.org', 'address': '충청남도 보은군 잠실로 402', 'phone': '055-066-1306'}
# {'id': 961, 'name': '이영식', 'email': 'yeongjin80@example.org', 'address': '충청북도 양주시 강남대646길 지하62', 'phone': '011-022-2309'}
# {'id': 962, 'name': '윤예진', 'email': 'ni@example.com', 'address': '대구광역시 노원구 봉은사거리 949 (서윤홍박동)', 'phone': '02-6370-8893'}
# {'id': 963, 'name': '이진우', 'email': 'igyeongsug@example.net', 'address': '전라북도 동해시 삼성길 204-25', 'phone': '010-4532-3932'}
# {'id': 964, 'name': '김명자', 'email': 'eyu@example.org', 'address': '전라북도 안산시 단원구 봉은사9거리 133', 'phone': '061-388-4677'}
# {'id': 965, 'name': '최정남', 'email': 'gimminji@example.com', 'address': '울산광역시 용산구 테헤란83가 299-95', 'phone': '016-398-5620'}
# {'id': 966, 'name': '이하윤', 'email': 'jaeho90@example.net', 'address': '경상남도 용인시 수지구 학동73거리 437-10 (미경최오리)', 'phone': '032-957-7660'}
# {'id': 967, 'name': '윤예지', 'email': 'bagsangho@example.net', 'address': '경상남도 천안시 서북구 반포대373로 208-56', 'phone': '010-4608-6116'}
# {'id': 968, 'name': '이경수', 'email': 'ui@example.com', 'address': '대구광역시 관악구 테헤란길 985-88 (정순민읍)', 'phone': '011-194-9101'}
# {'id': 969, 'name': '김성호', 'email': 'oi@example.com', 'address': '경기도 파주시 테헤란7거리 543-30 (영수김리)', 'phone': '053-125-9337'}
# {'id': 970, 'name': '김현지', 'email': 'imigyeong@example.net', 'address': '충청북도 수원시 팔달구 양재천4거리 604', 'phone': '010-4141-4479'}
# {'id': 971, 'name': '오민석', 'email': 'ggim@example.org', 'address': '전라북도 하남시 선릉246길 529-30 (정남김면)', 'phone': '016-711-9685'}
# {'id': 972, 'name': '손경수', 'email': 'hgweon@example.net', 'address': '충청남도 양양군 논현거리 540 (은정심한면)', 'phone': '031-089-7800'}
# {'id': 973, 'name': '황하윤', 'email': 'yeongil84@example.net', 'address': '충청북도 화성시 반포대가 964 (수진김마을)', 'phone': '055-568-9510'}
# {'id': 974, 'name': '이승현', 'email': 'ejang@example.org', 'address': '제주특별자치도 안양시 동안구 서초중앙7거리 110-76', 'phone': '019-468-6282'}
# {'id': 975, 'name': '배성현', 'email': 'seungminheo@example.net', 'address': '경기도 영동군 서초대5가 918-31 (명숙김동)', 'phone': '017-267-5514'}
# {'id': 976, 'name': '나민수', 'email': 'ti@example.com', 'address': '세종특별자치시 중랑구 논현가 159-77 (수진배박마을)', 'phone': '070-5795-4266'}
# {'id': 977, 'name': '김광수', 'email': 'dgim@example.com', 'address': '울산광역시 관악구 오금7길 479', 'phone': '043-915-4190'}
# {'id': 978, 'name': '장미영', 'email': 'gyeonghyi75@example.com', 'address': '경상남도 양평군 강남대로 812', 'phone': '033-340-7406'}
# {'id': 979, 'name': '이옥자', 'email': 'sanghyeoni@example.com', 'address': '세종특별자치시 서대문구 백제고분가 476', 'phone': '010-2482-8190'}
# {'id': 980, 'name': '박서윤', 'email': 'yeonghwan16@example.com', 'address': '강원도 안산시 역삼가 280-45 (미숙이리)', 'phone': '011-693-0079'}
# {'id': 981, 'name': '박영미', 'email': 'coeogsun@example.org', 'address': '서울특별시 종로구 삼성899거리 지하64', 'phone': '018-957-6665'}
# {'id': 982, 'name': '윤춘자', 'email': 'ucoe@example.org', 'address': '인천광역시 동대문구 잠실9가 484', 'phone': '011-418-9259'}
# {'id': 983, 'name': '이지훈', 'email': 'fi@example.net', 'address': '광주광역시 금천구 백제고분8로 750-93', 'phone': '051-138-1950'}
# {'id': 984, 'name': '박선영', 'email': 'bagseoyeong@example.net', 'address': '세종특별자치시 서구 백제고분683로 지하508', 'phone': '054-102-8814'}
# {'id': 985, 'name': '이중수', 'email': 'hyeonji65@example.com', 'address': '경상남도 홍천군 가락0로 570-44', 'phone': '053-113-8048'}
# {'id': 986, 'name': '박도윤', 'email': 'hyeonjun12@example.com', 'address': '충청남도 음성군 삼성9로 126-19', 'phone': '061-503-7829'}
# {'id': 987, 'name': '장주원', 'email': 'gimjiu@example.org', 'address': '인천광역시 송파구 반포대로 527', 'phone': '033-582-9016'}
# {'id': 988, 'name': '곽도현', 'email': 'igyeongsu@example.org', 'address': '광주광역시 은평구 석촌호수길 282-46', 'phone': '042-549-3185'}
# {'id': 989, 'name': '류현주', 'email': 'sonyeeun@example.com', 'address': '광주광역시 용산구 반포대97가 77-36 (영식이마을)', 'phone': '032-456-8936'}
# {'id': 990, 'name': '노미영', 'email': 'honghyeonu@example.com', 'address': '광주광역시 강동구 도산대630가 620-49 (재호백동)', 'phone': '011-343-2720'}
# {'id': 991, 'name': '최정호', 'email': 'yeongsun41@example.org', 'address': '경상북도 공주시 서초중앙가 93-49 (종수이이동)', 'phone': '042-632-8739'}
# {'id': 992, 'name': '최은영', 'email': 'jgim@example.com', 'address': '부산광역시 동대문구 언주403길 612-22', 'phone': '063-769-1792'}
# {'id': 993, 'name': '이명숙', 'email': 'yeongho81@example.org', 'address': '광주광역시 용산구 반포대469가 13 (민준유황면)', 'phone': '055-273-6117'}
# {'id': 994, 'name': '이정희', 'email': 'tgim@example.org', 'address': '경상북도 파주시 도산대3가 768-8', 'phone': '064-777-4213'}
# {'id': 995, 'name': '최현지', 'email': 'minjae84@example.net', 'address': '대구광역시 용산구 학동2거리 지하796', 'phone': '031-240-0807'}
# {'id': 996, 'name': '이성현', 'email': 'migyeong34@example.net', 'address': '세종특별자치시 강북구 학동가 119-6 (정웅백김면)', 'phone': '063-452-3467'}
# {'id': 997, 'name': '이은지', 'email': 'sunogi@example.org', 'address': '강원도 태백시 잠실길 590', 'phone': '062-836-8735'}
# {'id': 998, 'name': '최진우', 'email': 'lhan@example.org', 'address': '경기도 청주시 청원구 개포로 583-21 (진우김장면)', 'phone': '033-484-5769'}
# {'id': 999, 'name': '윤민서', 'email': 'uryu@example.org', 'address': '인천광역시 금천구 논현로 793 (명자김동)', 'phone': '052-863-8055'}
# {'id': 1000, 'name': '박성현', 'email': 'coesunja@example.net', 'address': '대구광역시 성동구 잠실가 989', 'phone': '062-360-6619'}

# %% [markdown]
# ## **과제 2. Tom이 Jerry를 쫒아가는 행위를 method(함수)로 만들어 보자(10번 following)**
#
# ### **class User:**
# > **def __init __ (self):**
# >   - ##### Initialize attributes
# >   - **HAS (Attiributes)**
#
# > **def following_mode():**
# >   - ##### change attributes (following, follower) for chasing
# >   - **Does (Method, Change the attributes)**
#
# <img src= 'https://pbs.twimg.com/profile_images/810136393/tom-jerry-pic_400x400.jpg' width=300>

# %%
# 사용자 클래스 정의
class User:
    def __init__(self, name):
        # 속성 초기화
        self.name = name
        self.following = 0
        self.follower = 0

    # following 동작 (Tom이 Jerry를 따라감)
    def following_mode(self, other_user):
        self.following += 1
        other_user.follower += 1


# 객체 생성
tom = User("Tom")
jerry = User("Jerry")

# Tom이 Jerry를 10번 따라감
for _ in range(10):
    tom.following_mode(jerry)

# 결과 출력
print(f"{tom.name} following: {tom.following}")
print(f"{jerry.name} follower: {jerry.follower}")
# Out:
# Tom following: 10
# Jerry follower: 10
